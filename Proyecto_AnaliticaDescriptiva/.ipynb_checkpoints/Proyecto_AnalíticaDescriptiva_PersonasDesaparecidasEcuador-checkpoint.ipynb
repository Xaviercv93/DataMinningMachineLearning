# %% [markdown]
# # Proyecto - Analítica Descriptiva
# ### Autor: Javier Criollo
# ### Fecha: 2023/06/06
#
# ## Tema: Se busca ver cuál es la provincia donde hubo más desaparecidos en Ecuador, encontrando el perfil de persona que es más frecuente a desaparecer.
# ## Objetivos:
# ### Determinar el perfil de persona que más desaparece por provincia.
# ### Categorizar los datos por rangos de edad.
# ### Determinar el mes donde hubo más desaparecidos, siendo los meses desde Enero a Abril.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calendar

# Carga el archivo CSV
datos = pd.read_csv('data/mdg_personasdesaparecidas_pm_2023_enero_abril.csv', encoding='latin1', sep=';')

# Imprime los datos
# print(datos)

# %%
# Imprimir las columnas del dataset
columnas = datos.columns
print(columnas)
# Out:
# Index(['Provincia', 'Latitud', 'Longitud', 'Edad Aprox.', 'Sexo',
#        'Motivo Desaparción', 'Motivo Desaparción Obs.', 'Fecha Desaparición',
#        'Situación Actual', 'Fecha Localización'],
#       dtype='object')

# %%
# Load the dataset from a CSV file
df = datos

# Group the records by age and sex, and count the number of occurrences 
#grouped_counts2 = df.groupby(['Edad Aprox.', 'Sexo','Motivo Desaparción'])['Provincia'].count().reset_index()
agrupadoProvincia = df.groupby('Provincia')
for Provincia, data in agrupadoProvincia:
    print(f'Provincia:{Provincia}')
    print(data.head(10))
    print('----------------------------------------------------------------------------------------------')
# Print the grouped counts
print(agrupadoProvincia)
# Out:
# Provincia:AZUAY
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 14      AZUAY  -2,89018174  -79,02961728            1   MUJER
# 18      AZUAY  -2,89328886   -78,9994653           23  HOMBRE
# 29      AZUAY  -2,87178367  -79,06679508           64  HOMBRE
# 38      AZUAY    -2,979583   -79,6848909           20  HOMBRE
# 40      AZUAY  -2,88142599  -79,00526814           47   MUJER
# 69      AZUAY   -2,9100879   -79,0349661           25  HOMBRE
# 162     AZUAY  -2,92674978  -79,05076146           17   MUJER
# 182     AZUAY   -2,8870218   -78,9641763           19   MUJER
# 183     AZUAY  -2,91418544  -79,00084692           15   MUJER
# 184     AZUAY  -2,91418544  -79,00084692           15  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 14   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          18/3/2023
# 18     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          19/3/2023
# 29     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          30/1/2023
# 38               SIN_DATO                 SIN_DATO          11/1/2023
# 40     PROBLEMAS SOCIALES             DELINCUENCIA          17/1/2023
# 69               SIN_DATO                 SIN_DATO          21/4/2023
# 162  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          15/2/2023
# 182  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          27/1/2023
# 183  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          25/1/2023
# 184  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          25/1/2023
#
#     Situación Actual Fecha Localización
# 14        ENCONTRADO           6/4/2023
# 18        ENCONTRADO          22/3/2023
# 29        ENCONTRADO           4/3/2023
# 38      DESAPARECIDO           SIN_DATO
# 40        ENCONTRADO          22/1/2023
# 69      DESAPARECIDO           SIN_DATO
# 162       ENCONTRADO          16/3/2023
# 182       ENCONTRADO           5/2/2023
# 183       ENCONTRADO           5/2/2023
# 184       ENCONTRADO           5/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:BOLIVAR
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 245   BOLIVAR    -1,578807  -79,00321869           16  HOMBRE
# 559   BOLIVAR  -1,80833099  -79,10103968           29   MUJER
# 562   BOLIVAR   -1,5911691   -78,9990379           16   MUJER
# 565   BOLIVAR   -1,5585611   -79,0093181           12   MUJER
# 614   BOLIVAR  -1,52057063    -79,003987           16  HOMBRE
# 729   BOLIVAR  -1,58266894   -78,9969058            9   MUJER
# 759   BOLIVAR  -1,59170274  -79,03335238           17   MUJER
# 763   BOLIVAR  -1,59757006  -78,96793152           17   MUJER
# 803   BOLIVAR   -1,5585611   -79,0093181           45  HOMBRE
# 900   BOLIVAR  -1,63187661  -79,25745644           13   MUJER
#
#          Motivo Desaparción      Motivo Desaparción Obs. Fecha Desaparición  \
# 245      PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES          26/2/2023
# 559                SIN_DATO                     SIN_DATO          20/4/2023
# 562    PROBLEMAS ACADÉMICOS             BAJO RENDIMIENTO           3/1/2023
# 565                SIN_DATO                     SIN_DATO          18/4/2023
# 614  PROBLEMAS PSICOLÓGICOS                    DEPRESION           7/1/2023
# 729    PROBLEMAS ACADÉMICOS  BULLYING (MALTRATO ESCOLAR)          17/1/2023
# 759      PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES           3/1/2023
# 763    PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES          14/1/2023
# 803                SIN_DATO                     SIN_DATO           7/2/2023
# 900      PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES          17/1/2023
#
#     Situación Actual Fecha Localización
# 245       ENCONTRADO           1/3/2023
# 559     DESAPARECIDO           SIN_DATO
# 562       ENCONTRADO           4/1/2023
# 565     DESAPARECIDO           SIN_DATO
# 614       ENCONTRADO           9/1/2023
# 729       ENCONTRADO          17/1/2023
# 759       ENCONTRADO          18/1/2023
# 763       ENCONTRADO          18/1/2023
# 803     DESAPARECIDO           SIN_DATO
# 900       ENCONTRADO          22/1/2023
# ----------------------------------------------------------------------------------------------
# Provincia:CARCHI
#      Provincia     Latitud      Longitud  Edad Aprox.    Sexo  \
# 16      CARCHI   0,5948949   -77,8281514           79  HOMBRE
# 37      CARCHI   0,8199273  -77,71331504           17   MUJER
# 44      CARCHI   0,5948949   -77,8281514           19   MUJER
# 105     CARCHI  0,82232453  -77,70438416           16   MUJER
# 127     CARCHI   0,6340391   -77,7337628           15   MUJER
# 136     CARCHI   0,5948949   -77,8281514           78  HOMBRE
# 503     CARCHI  0,82939769  -77,70315855           17   MUJER
# 569     CARCHI  0,80150142  -77,73244282           56  HOMBRE
# 845     CARCHI   0,8150687   -77,7165925           14  HOMBRE
# 1123    CARCHI   0,5105725   -77,8667416           13   MUJER
#
#         Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 16    PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          13/3/2023
# 37      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          12/1/2023
# 44      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          28/1/2023
# 105   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          17/4/2023
# 127     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          10/4/2023
# 136               SIN_DATO                 SIN_DATO           1/4/2023
# 503   PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          28/2/2023
# 569     PROBLEMAS SOCIALES              ALCOHOLISMO           2/1/2023
# 845     PROBLEMAS SOCIALES             DROGADICCION          21/1/2023
# 1123  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          28/1/2023
#
#      Situación Actual Fecha Localización
# 16         ENCONTRADO          22/3/2023
# 37         ENCONTRADO          16/1/2023
# 44         ENCONTRADO          31/1/2023
# 105        ENCONTRADO           3/5/2023
# 127        ENCONTRADO          11/4/2023
# 136      DESAPARECIDO           SIN_DATO
# 503        ENCONTRADO          28/2/2023
# 569        ENCONTRADO           5/1/2023
# 845        ENCONTRADO          22/1/2023
# 1123       ENCONTRADO           7/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:CAÑAR
#      Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 156      CAÑAR  -2,74420725   -78,8606357           15   MUJER
# 204      CAÑAR  -2,41859254  -79,34606481           12   MUJER
# 210      CAÑAR  -2,43107356   -79,3379348           14   MUJER
# 273      CAÑAR  -2,55980032  -78,93751322           24  HOMBRE
# 640      CAÑAR   -2,4967536  -79,47998164           14   MUJER
# 1038     CAÑAR  -2,73786305  -78,84501452           14   MUJER
# 1050     CAÑAR  -2,52724371  -78,91291016           32   MUJER
# 1389     CAÑAR  -2,44971945   -79,3188858           52  HOMBRE
# 1398     CAÑAR  -2,42751698  -79,34290006           16   MUJER
# 1425     CAÑAR  -2,51183374  -78,92759869           16  HOMBRE
#
#         Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 156   PROBLEMAS FAMILIARES     MALTRATO PSICOLOGICO           3/1/2023
# 204               SIN_DATO                 SIN_DATO           8/2/2023
# 210   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           3/1/2023
# 273   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           5/2/2023
# 640   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           9/1/2023
# 1038  PROBLEMAS FAMILIARES          MALTRATO FISICO          30/1/2023
# 1050  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          31/1/2023
# 1389  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          18/1/2023
# 1398  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           5/1/2023
# 1425    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          19/2/2023
#
#      Situación Actual Fecha Localización
# 156        ENCONTRADO          25/1/2023
# 204      DESAPARECIDO           SIN_DATO
# 210        ENCONTRADO          13/1/2023
# 273        ENCONTRADO          22/2/2023
# 640        ENCONTRADO          15/1/2023
# 1038       ENCONTRADO           3/2/2023
# 1050       ENCONTRADO          14/2/2023
# 1389       ENCONTRADO          24/2/2023
# 1398       ENCONTRADO          25/2/2023
# 1425       ENCONTRADO          24/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:CHIMBORAZO
#       Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 8    CHIMBORAZO   -1,6604411   -78,6563855           12  HOMBRE
# 89   CHIMBORAZO  -1,67127269    -78,653761           20  HOMBRE
# 176  CHIMBORAZO    -2,206582   -79,1336706           17   MUJER
# 187  CHIMBORAZO   -1,6071779   -78,6310395           28   MUJER
# 198  CHIMBORAZO   -1,9372504   -78,7140798           44  HOMBRE
# 281  CHIMBORAZO   -1,6943845   -78,6284105            3  HOMBRE
# 291  CHIMBORAZO  -1,68939198  -78,63477297           17   MUJER
# 292  CHIMBORAZO  -1,64699845  -78,68169349           14   MUJER
# 301  CHIMBORAZO   -1,6775352   -78,6586231           26   MUJER
# 360  CHIMBORAZO   -1,6650227   -78,6588786           21  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 8    PROBLEMAS FAMILIARES          MALTRATO FISICO           9/2/2023
# 89     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          11/3/2023
# 176    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          24/1/2023
# 187    PROBLEMAS SOCIALES             DELINCUENCIA           6/3/2023
# 198  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           2/3/2023
# 281  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          14/2/2023
# 291              SIN_DATO                 SIN_DATO           5/3/2023
# 292  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          15/3/2023
# 301  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          15/2/2023
# 360   PROBLEMA ECÓNOMICOS                   DEUDAS          18/3/2023
#
#     Situación Actual Fecha Localización
# 8         ENCONTRADO           9/2/2023
# 89        ENCONTRADO          13/3/2023
# 176       ENCONTRADO          18/4/2023
# 187       ENCONTRADO          17/3/2023
# 198       ENCONTRADO          17/3/2023
# 281       ENCONTRADO          14/2/2023
# 291     DESAPARECIDO           SIN_DATO
# 292       ENCONTRADO          18/3/2023
# 301       ENCONTRADO          11/4/2023
# 360       ENCONTRADO          20/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:COTOPAXI
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 120  COTOPAXI  -0,93972373  -78,60730939           16  HOMBRE
# 121  COTOPAXI   -0,9254446  -78,62030673            6  HOMBRE
# 130  COTOPAXI  -1,03443261  -78,58218155           15   MUJER
# 160  COTOPAXI  -0,90607243  -78,70018485           19   MUJER
# 181  COTOPAXI   -0,9411949   -79,2316042           15   MUJER
# 186  COTOPAXI  -1,03458907  -78,48614605           49  HOMBRE
# 240  COTOPAXI  -1,04558505  -78,59021008           14   MUJER
# 294  COTOPAXI  -0,83476094  -78,66754145           16   MUJER
# 372  COTOPAXI  -0,93109558  -78,59627176           26  HOMBRE
# 374  COTOPAXI  -0,93485067  -78,57064773           16   MUJER
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 120  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           7/4/2023
# 121  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           6/4/2023
# 130  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          10/4/2023
# 160    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           3/2/2023
# 181  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           1/1/2023
# 186    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          15/3/2023
# 240    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          16/3/2023
# 294    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          17/3/2023
# 372    PROBLEMAS SOCIALES              ALCOHOLISMO          18/2/2023
# 374    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          17/2/2023
#
#     Situación Actual Fecha Localización
# 120       ENCONTRADO           9/4/2023
# 121       ENCONTRADO           7/4/2023
# 130       ENCONTRADO          17/4/2023
# 160       ENCONTRADO          15/3/2023
# 181       ENCONTRADO           3/2/2023
# 186       ENCONTRADO          17/3/2023
# 240       ENCONTRADO          18/3/2023
# 294       ENCONTRADO          19/3/2023
# 372       ENCONTRADO           9/3/2023
# 374       ENCONTRADO          13/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:EL ORO
#    Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 43    EL ORO  -3,25847541  -79,95848846           22  HOMBRE
# 54    EL ORO  -3,24463384   -79,9721539           26   MUJER
# 57    EL ORO  -3,25624537  -79,95379046           17  HOMBRE
# 59    EL ORO  -3,47640684  -80,22280228           52  HOMBRE
# 60    EL ORO  -3,32726864  -79,79608727           40  HOMBRE
# 67    EL ORO  -3,24525766  -79,95017177           25  HOMBRE
# 71    EL ORO  -3,26526917  -79,95803565           16   MUJER
# 73    EL ORO  -3,25099267   -79,9442594           24  HOMBRE
# 77    EL ORO  -3,48133347  -80,24296706           54  HOMBRE
# 79    EL ORO  -3,25466457  -79,96235847           25  HOMBRE
#
#                Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 43             PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           8/1/2023
# 54             PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          30/1/2023
# 57  DISCAPACIDADES Y ENFERMEDADES        RETARDOS MENTALES          24/1/2023
# 59                     EXTRAVIADA       PERSONA EXTRAVIADA           1/2/2023
# 60           PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          28/2/2023
# 67             PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          31/1/2023
# 71           PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           5/3/2023
# 73             PROBLEMAS SOCIALES             DELINCUENCIA          21/4/2023
# 77                      FALLECIDO               ACCIDENTAL          23/3/2023
# 79            PROBLEMA ECÓNOMICOS                   DEUDAS           7/3/2023
#
#    Situación Actual Fecha Localización
# 43       ENCONTRADO          26/1/2023
# 54       ENCONTRADO           3/2/2023
# 57       ENCONTRADO          24/1/2023
# 59       ENCONTRADO           6/2/2023
# 60       ENCONTRADO           9/3/2023
# 67       ENCONTRADO           1/3/2023
# 71       ENCONTRADO           8/3/2023
# 73       ENCONTRADO          25/4/2023
# 77        FALLECIDO          25/4/2023
# 79       ENCONTRADO          10/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:ESMERALDAS
#       Provincia     Latitud      Longitud  Edad Aprox.    Sexo  \
# 4    ESMERALDAS   0,9873857  -79,65649069           28  HOMBRE
# 61   ESMERALDAS  1,28340478  -78,83600235           27   MUJER
# 63   ESMERALDAS  0,90186627  -79,68476051           14   MUJER
# 64   ESMERALDAS   1,2756605    -78,846488            3  HOMBRE
# 82   ESMERALDAS    0,533362   -79,5227688           31  HOMBRE
# 83   ESMERALDAS    0,533362   -79,5227688           45  HOMBRE
# 125  ESMERALDAS  0,90063463  -79,69350827           14   MUJER
# 169  ESMERALDAS  0,90253514  -79,68485017           22  HOMBRE
# 218  ESMERALDAS  0,96224533  -79,65630486           13   MUJER
# 342  ESMERALDAS  0,96365617  -79,66118926           15  HOMBRE
#
#          Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 4                  SIN_DATO                 SIN_DATO           7/2/2023
# 61   PROBLEMAS PSICOLÓGICOS    PROBLEMAS DE CONDUCTA          21/1/2023
# 63                 SIN_DATO                 SIN_DATO          12/2/2023
# 64     PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           6/2/2023
# 82                 SIN_DATO                 SIN_DATO          28/3/2023
# 83                 SIN_DATO                 SIN_DATO          28/3/2023
# 125                SIN_DATO                 SIN_DATO           9/4/2023
# 169               FALLECIDO                ASESINATO           3/3/2023
# 218                SIN_DATO                 SIN_DATO          22/2/2023
# 342    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          19/3/2023
#
#     Situación Actual Fecha Localización
# 4       DESAPARECIDO           SIN_DATO
# 61        ENCONTRADO           7/2/2023
# 63      DESAPARECIDO           SIN_DATO
# 64        ENCONTRADO          10/2/2023
# 82      DESAPARECIDO           SIN_DATO
# 83      DESAPARECIDO           SIN_DATO
# 125     DESAPARECIDO           SIN_DATO
# 169        FALLECIDO           5/3/2023
# 218     DESAPARECIDO           SIN_DATO
# 342       ENCONTRADO          22/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:GALAPAGOS
#       Provincia     Latitud     Longitud  Edad Aprox.    Sexo  \
# 1948  GALAPAGOS  -0,7386498  -90,3126872           41  HOMBRE
# 2243  GALAPAGOS  0,13864128  -91,3480686           49  HOMBRE
# 2245  GALAPAGOS  -0,7432918  -90,3156893           15   MUJER
# 2369  GALAPAGOS  -0,8674715   -89,436391           26  HOMBRE
#
#         Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 1948    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          31/3/2023
# 2243            EXTRAVIADA              ACCIDENTADO          12/4/2023
# 2245  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          12/4/2023
# 2369    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          13/4/2023
#
#      Situación Actual Fecha Localización
# 1948       ENCONTRADO           3/4/2023
# 2243       ENCONTRADO          13/4/2023
# 2245       ENCONTRADO          13/4/2023
# 2369       ENCONTRADO          16/4/2023
# ----------------------------------------------------------------------------------------------
# Provincia:GUAYAS
#    Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 5     GUAYAS   -2,1225293    -80,000135           28  HOMBRE
# 7     GUAYAS   -2,1258684   -79,9227452           16   MUJER
# 11    GUAYAS  -2,11391357  -79,98889708           21   MUJER
# 22    GUAYAS  -2,06302898  -79,94972714           16  HOMBRE
# 25    GUAYAS   -2,2438091   -79,9066763           15   MUJER
# 27    GUAYAS    -1,797673    -80,026285           52  HOMBRE
# 34    GUAYAS   -2,0646512   -79,8926809           15   MUJER
# 35    GUAYAS  -2,26935613  -79,75955774           13   MUJER
# 39    GUAYAS   -2,0145451   -79,9259385           15   MUJER
# 48    GUAYAS  -2,62767924  -80,40004703            4  HOMBRE
#
#         Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 5                FALLECIDO           NO DETERMINADA          15/3/2023
# 7     PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           2/3/2023
# 11  PROBLEMAS PSICOLÓGICOS                DEPRESION          18/3/2023
# 22                SIN_DATO                 SIN_DATO          18/3/2023
# 25      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          23/3/2023
# 27                SIN_DATO                 SIN_DATO          29/1/2023
# 34                SIN_DATO                 SIN_DATO           2/3/2023
# 35    PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          31/1/2023
# 39    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          15/1/2023
# 48    PROBLEMAS FAMILIARES          MALTRATO FISICO          24/1/2023
#
#    Situación Actual Fecha Localización
# 5         FALLECIDO          24/3/2023
# 7        ENCONTRADO          20/3/2023
# 11       ENCONTRADO          28/3/2023
# 22     DESAPARECIDO           SIN_DATO
# 25       ENCONTRADO          28/3/2023
# 27     DESAPARECIDO           SIN_DATO
# 34     DESAPARECIDO           SIN_DATO
# 35       ENCONTRADO           5/2/2023
# 39       ENCONTRADO          17/1/2023
# 48       ENCONTRADO           2/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:IMBABURA
#     Provincia     Latitud      Longitud  Edad Aprox.    Sexo  \
# 10   IMBABURA   0,3475869   -78,1160486           23  HOMBRE
# 30   IMBABURA   0,3552973   -78,1250848           17  HOMBRE
# 32   IMBABURA   0,3552973   -78,1250848           17  HOMBRE
# 33   IMBABURA  0,34576683  -78,13592434           45   MUJER
# 78   IMBABURA   0,3471469   -78,1323648           29  HOMBRE
# 81   IMBABURA   0,3281312     -78,12206           16  HOMBRE
# 98   IMBABURA  0,36012314  -78,09260654            1  HOMBRE
# 99   IMBABURA  0,34548863  -78,12106301           16  HOMBRE
# 171  IMBABURA  0,34185128  -78,16467047           13   MUJER
# 200  IMBABURA   0,1946244   -78,0920719           60  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 10     PROBLEMAS SOCIALES             DELINCUENCIA          10/3/2023
# 30               SIN_DATO                 SIN_DATO          23/2/2023
# 32     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           4/2/2023
# 33     PROBLEMAS SOCIALES             DELINCUENCIA          22/2/2023
# 78     PROBLEMAS SOCIALES                MIGRACION          12/2/2023
# 81               SIN_DATO                 SIN_DATO          22/4/2023
# 98   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           4/4/2023
# 99               SIN_DATO                 SIN_DATO           1/4/2023
# 171    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          18/2/2023
# 200            EXTRAVIADA       PERSONA EXTRAVIADA          10/3/2023
#
#     Situación Actual Fecha Localización
# 10        ENCONTRADO          16/3/2023
# 30      DESAPARECIDO           SIN_DATO
# 32        ENCONTRADO           3/3/2023
# 33        ENCONTRADO           4/3/2023
# 78        ENCONTRADO          25/4/2023
# 81      DESAPARECIDO           SIN_DATO
# 98        ENCONTRADO           4/4/2023
# 99      DESAPARECIDO           SIN_DATO
# 171       ENCONTRADO           1/3/2023
# 200       ENCONTRADO          17/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:LOJA
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 80       LOJA   -4,0282595   -79,2088096           36   MUJER
# 196      LOJA  -4,00293028  -79,21007902            5   MUJER
# 209      LOJA  -4,00293028  -79,21007902           22   MUJER
# 214      LOJA  -4,03282312  -79,20254698           55  HOMBRE
# 220      LOJA   -3,9098046   -79,2888043           78  HOMBRE
# 237      LOJA   -3,9865964  -79,20339546           16   MUJER
# 298      LOJA   -4,0455072   -79,7848422            6   MUJER
# 317      LOJA  -4,00606383  -79,20419709           48  HOMBRE
# 320      LOJA   -4,0455072   -79,7848422           27  HOMBRE
# 355      LOJA   -3,9861935   -79,2056456           23  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 80   PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          31/3/2023
# 196  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          26/2/2023
# 209  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          26/2/2023
# 214             FALLECIDO           NO DETERMINADA           7/1/2023
# 220              SIN_DATO                 SIN_DATO           8/2/2023
# 237  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          26/2/2023
# 298             FALLECIDO           NO DETERMINADA          17/3/2023
# 317    PROBLEMAS SOCIALES              ALCOHOLISMO           9/3/2023
# 320  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           5/3/2023
# 355    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          17/3/2023
#
#     Situación Actual Fecha Localización
# 80        ENCONTRADO           5/4/2023
# 196       ENCONTRADO           1/3/2023
# 209       ENCONTRADO           1/3/2023
# 214        FALLECIDO           9/1/2023
# 220     DESAPARECIDO           SIN_DATO
# 237       ENCONTRADO          28/2/2023
# 298        FALLECIDO          19/3/2023
# 317       ENCONTRADO          20/3/2023
# 320       ENCONTRADO          21/3/2023
# 355       ENCONTRADO          18/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:LOS RIOS
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 19   LOS RIOS   -1,0336635   -79,4506989            3   MUJER
# 52   LOS RIOS  -0,96617922  -79,42054382            4   MUJER
# 53   LOS RIOS  -0,72860049  -79,47111598           15   MUJER
# 134  LOS RIOS   -0,9943373    -79,473904           15  HOMBRE
# 135  LOS RIOS   -1,0395683   -79,4569217           14   MUJER
# 150  LOS RIOS  -1,56068095  -79,75473404           12   MUJER
# 167  LOS RIOS    -0,992388     -79,47287           17   MUJER
# 205  LOS RIOS  -1,80903409  -79,53475428           36  HOMBRE
# 229  LOS RIOS  -1,56068095  -79,75473404           13   MUJER
# 233  LOS RIOS  -1,44546059  -79,46475983           11  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 19     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          12/3/2023
# 52   PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           1/2/2023
# 53   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          21/1/2023
# 134  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           8/4/2023
# 135  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          10/4/2023
# 150  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          16/1/2023
# 167    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          24/2/2023
# 205              SIN_DATO                 SIN_DATO          18/2/2023
# 229  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          13/2/2023
# 233  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          29/1/2023
#
#     Situación Actual Fecha Localización
# 19        ENCONTRADO          16/3/2023
# 52        ENCONTRADO           2/2/2023
# 53        ENCONTRADO           2/2/2023
# 134       ENCONTRADO          18/4/2023
# 135       ENCONTRADO          18/4/2023
# 150       ENCONTRADO          20/1/2023
# 167       ENCONTRADO          15/3/2023
# 205     DESAPARECIDO           SIN_DATO
# 229       ENCONTRADO          15/2/2023
# 233       ENCONTRADO           1/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:MANABI
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 12     MANABI  -0,95853387  -80,74264526           17   MUJER
# 13     MANABI  -0,95853387  -80,74264526            2  HOMBRE
# 15     MANABI  -0,84977849  -80,53141594           15   MUJER
# 20     MANABI    0,0731181   -80,0513928           37  HOMBRE
# 66     MANABI  -1,03054033  -80,46416759           15   MUJER
# 68     MANABI  -1,03371019  -80,45318127           15   MUJER
# 75     MANABI    -0,952035    -80,459198            1  HOMBRE
# 154    MANABI  -1,39584253  -80,20675993           17   MUJER
# 170    MANABI  -0,35123859  -79,60800961           18   MUJER
# 174    MANABI  -1,06458656  -80,44917558           19  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 12   PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          26/2/2023
# 13   PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          26/2/2023
# 15   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          19/2/2023
# 20     PROBLEMAS SOCIALES             DELINCUENCIA          14/1/2023
# 66     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           3/2/2023
# 68   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          22/2/2023
# 75               SIN_DATO                 SIN_DATO          25/4/2023
# 154              SIN_DATO                 SIN_DATO           9/1/2023
# 170  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          21/2/2023
# 174    PROBLEMAS SOCIALES             DROGADICCION          21/1/2023
#
#     Situación Actual Fecha Localización
# 12        ENCONTRADO          22/3/2023
# 13        ENCONTRADO          22/3/2023
# 15        ENCONTRADO          23/2/2023
# 20        ENCONTRADO          22/3/2023
# 66        ENCONTRADO          21/2/2023
# 68        ENCONTRADO          23/2/2023
# 75      DESAPARECIDO           SIN_DATO
# 154     DESAPARECIDO           SIN_DATO
# 170       ENCONTRADO           1/3/2023
# 174       ENCONTRADO           1/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:MORONA SANTIAGO
#            Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 133  MORONA SANTIAGO  -2,30501622  -78,12276321           16  HOMBRE
# 152  MORONA SANTIAGO  -2,30535927  -78,12207657           16  HOMBRE
# 380  MORONA SANTIAGO   -2,4566285   -78,1678439           14   MUJER
# 419  MORONA SANTIAGO   -2,3074378   -78,1202307           19   MUJER
# 428  MORONA SANTIAGO  -2,24778132  -78,14267636           11  HOMBRE
# 448  MORONA SANTIAGO   -2,3074378   -78,1202307           15   MUJER
# 451  MORONA SANTIAGO  -2,24778132  -78,14267636            6  HOMBRE
# 527  MORONA SANTIAGO  -3,40598911  -78,57586859           16   MUJER
# 544  MORONA SANTIAGO    -3,281317  -78,64575922           17   MUJER
# 555  MORONA SANTIAGO  -2,30754679  -78,12044145           15   MUJER
#
#          Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 133      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           2/4/2023
# 152      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          30/3/2023
# 380      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           6/3/2023
# 419      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          19/3/2023
# 428  PROBLEMAS PSICOLÓGICOS    PROBLEMAS DE CONDUCTA          21/3/2023
# 448    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          25/2/2023
# 451  PROBLEMAS PSICOLÓGICOS    PROBLEMAS DE CONDUCTA          21/3/2023
# 527    PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           1/3/2023
# 544    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          25/2/2023
# 555      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           3/1/2023
#
#     Situación Actual Fecha Localización
# 133       ENCONTRADO          14/4/2023
# 152       ENCONTRADO          11/5/2023
# 380       ENCONTRADO          22/3/2023
# 419       ENCONTRADO          22/3/2023
# 428       ENCONTRADO          23/3/2023
# 448       ENCONTRADO           2/4/2023
# 451       ENCONTRADO          23/3/2023
# 527       ENCONTRADO          17/4/2023
# 544       ENCONTRADO           3/3/2023
# 555       ENCONTRADO           4/1/2023
# ----------------------------------------------------------------------------------------------
# Provincia:NAPO
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 47       NAPO  -0,93259508  -77,77341843           25  HOMBRE
# 76       NAPO  -1,05352205  -77,54830221           21  HOMBRE
# 177      NAPO  -1,03486871  -77,66340494           25  HOMBRE
# 206      NAPO  -0,99881192   -77,8053598           14   MUJER
# 221      NAPO  -1,18959302  -77,87216496           17   MUJER
# 381      NAPO  -0,97868404  -77,85237944           16   MUJER
# 415      NAPO   -1,1650467   -77,8553089           15   MUJER
# 512      NAPO  -1,04290569   -77,8022923           33  HOMBRE
# 520      NAPO  -1,04243501  -77,79514038           16   MUJER
# 676      NAPO   -0,9962972   -77,8136035           34  HOMBRE
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 47             EXTRAVIADA       PERSONA EXTRAVIADA          15/1/2023
# 76   PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           5/3/2023
# 177             FALLECIDO           NO DETERMINADA           1/1/2023
# 206    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           3/1/2023
# 221  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          13/3/2023
# 381  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          11/3/2023
# 415    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           6/1/2023
# 512    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           8/3/2023
# 520  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          24/2/2023
# 676  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           8/4/2023
#
#     Situación Actual Fecha Localización
# 47        ENCONTRADO           1/2/2023
# 76        ENCONTRADO           9/3/2023
# 177        FALLECIDO           3/1/2023
# 206       ENCONTRADO           8/1/2023
# 221       ENCONTRADO          18/3/2023
# 381       ENCONTRADO          15/3/2023
# 415       ENCONTRADO           2/3/2023
# 512       ENCONTRADO          23/3/2023
# 520       ENCONTRADO          26/3/2023
# 676       ENCONTRADO          21/4/2023
# ----------------------------------------------------------------------------------------------
# Provincia:ORELLANA
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 46   ORELLANA   -0,4616728   -76,9931074           12  HOMBRE
# 129  ORELLANA   -0,4616728   -76,9931074           15  HOMBRE
# 148  ORELLANA   -0,4616728   -76,9931074           15   MUJER
# 228  ORELLANA  -0,30122487  -76,85641116           11  HOMBRE
# 235  ORELLANA    -0,333333           -77           14   MUJER
# 384  ORELLANA   -0,4545163   -76,9950286           15  HOMBRE
# 605  ORELLANA  -0,40800634  -76,99652435           12   MUJER
# 606  ORELLANA  -0,45429547  -77,01182256           16   MUJER
# 752  ORELLANA   -0,4616728   -76,9931074           35  HOMBRE
# 844  ORELLANA  -0,44281948  -77,00877681           29   MUJER
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 46   PROBLEMAS FAMILIARES          MALTRATO FISICO          26/1/2023
# 129    PROBLEMAS SOCIALES             DELINCUENCIA           3/4/2023
# 148    PROBLEMAS SOCIALES             DROGADICCION          30/4/2023
# 228  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           5/1/2023
# 235    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          21/2/2023
# 384    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          10/2/2023
# 605    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           1/1/2023
# 606  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           8/1/2023
# 752    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           5/3/2023
# 844    PROBLEMAS SOCIALES             DROGADICCION           2/1/2023
#
#     Situación Actual Fecha Localización
# 46        ENCONTRADO           1/2/2023
# 129       ENCONTRADO          11/4/2023
# 148       ENCONTRADO          12/5/2023
# 228       ENCONTRADO          19/1/2023
# 235       ENCONTRADO           1/3/2023
# 384       ENCONTRADO          13/3/2023
# 605       ENCONTRADO           2/2/2023
# 606       ENCONTRADO          20/1/2023
# 752       ENCONTRADO           7/3/2023
# 844       ENCONTRADO          23/1/2023
# ----------------------------------------------------------------------------------------------
# Provincia:PASTAZA
#      Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 139    PASTAZA   -1,4840175   -78,0103037           15   MUJER
# 166    PASTAZA  -1,91231652  -77,71695361           15   MUJER
# 432    PASTAZA  -1,26448738  -77,89049819           26  HOMBRE
# 664    PASTAZA  -1,49468909  -78,01431722           26   MUJER
# 784    PASTAZA  -1,47947312  -78,01176509            5  HOMBRE
# 789    PASTAZA  -1,47947312  -78,01176509            7   MUJER
# 977    PASTAZA  -1,50077698  -78,06668755           18   MUJER
# 1000   PASTAZA  -1,48597399  -78,00619786           20  HOMBRE
# 1186   PASTAZA  -1,48082317  -78,00107988           20   MUJER
# 1277   PASTAZA  -1,45784234  -77,90590808           16   MUJER
#
#                  Motivo Desaparción      Motivo Desaparción Obs.  \
# 139            PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES
# 166              PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES
# 432   DISCAPACIDADES Y ENFERMEDADES  OTRAS ENFERMEDADES MENTALES
# 664            PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES
# 784          PROBLEMAS PSICOLÓGICOS        PROBLEMAS DE CONDUCTA
# 789          PROBLEMAS PSICOLÓGICOS        PROBLEMAS DE CONDUCTA
# 977              PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES
# 1000             PROBLEMAS SOCIALES                 DELINCUENCIA
# 1186             PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES
# 1277             PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES
#
#      Fecha Desaparición Situación Actual Fecha Localización
# 139           10/4/2023       ENCONTRADO          12/4/2023
# 166           25/1/2023       ENCONTRADO          29/1/2023
# 432           20/3/2023       ENCONTRADO           5/4/2023
# 664           12/3/2023       ENCONTRADO          27/3/2023
# 784            5/3/2023       ENCONTRADO           6/3/2023
# 789            5/3/2023       ENCONTRADO           6/3/2023
# 977           28/1/2023       ENCONTRADO          31/1/2023
# 1000          28/1/2023       ENCONTRADO          31/1/2023
# 1186           5/2/2023       ENCONTRADO          12/2/2023
# 1277          14/2/2023       ENCONTRADO          16/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:PICHINCHA
#     Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 0   PICHINCHA   -0,2188216   -78,5135489           17  HOMBRE
# 1   PICHINCHA  -0,26909023  -78,54001523           17   MUJER
# 3   PICHINCHA  -0,17504166  -78,47478184           14   MUJER
# 9   PICHINCHA  -0,21867203  -78,50517916           16   MUJER
# 17  PICHINCHA   -0,2930405   -78,5497592           38  HOMBRE
# 24  PICHINCHA   -0,3314841   -78,4254543           69   MUJER
# 26  PICHINCHA    -0,204459   -78,3426905           16  HOMBRE
# 28  PICHINCHA  -0,27768447  -78,55758901           23  HOMBRE
# 36  PICHINCHA   -0,1044341   -78,4846548           14   MUJER
# 45  PICHINCHA    0,0015208   -78,2186045            2   MUJER
#
#                Motivo Desaparción      Motivo Desaparción Obs.  \
# 0                        SIN_DATO                     SIN_DATO
# 1            PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES
# 3              PROBLEMAS SOCIALES      INFLUENCIA DE AMISTADES
# 9                        SIN_DATO                     SIN_DATO
# 17                      FALLECIDO               NO DETERMINADA
# 24  DISCAPACIDADES Y ENFERMEDADES  OTRAS ENFERMEDADES MENTALES
# 26           PROBLEMAS FAMILIARES         FAMILIA DISFUNSIONAL
# 28  DISCAPACIDADES Y ENFERMEDADES  OTRAS ENFERMEDADES MENTALES
# 36           PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES
# 45           PROBLEMAS FAMILIARES              MALTRATO FISICO
#
#    Fecha Desaparición Situación Actual Fecha Localización
# 0           24/1/2023     DESAPARECIDO           SIN_DATO
# 1            2/2/2023       ENCONTRADO           7/2/2023
# 3           16/3/2023       ENCONTRADO          17/3/2023
# 9           17/3/2023     DESAPARECIDO           SIN_DATO
# 17          15/3/2023        FALLECIDO           1/4/2023
# 24          13/3/2023       ENCONTRADO          24/3/2023
# 26           8/2/2023       ENCONTRADO          28/2/2023
# 28           7/2/2023       ENCONTRADO           9/3/2023
# 36          27/3/2023       ENCONTRADO          27/3/2023
# 45          11/3/2023       ENCONTRADO          21/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:SANTA ELENA
#        Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 65   SANTA ELENA    -2,250219    -80,920593            1   MUJER
# 103  SANTA ELENA   -1,7596823   -80,7699552           81   MUJER
# 124  SANTA ELENA  -2,22726954  -80,90266186           16   MUJER
# 131  SANTA ELENA    -2,241402    -80,887382           15   MUJER
# 185  SANTA ELENA   -2,3127597  -80,70610553           26  HOMBRE
# 282  SANTA ELENA  -2,22054988  -80,86332819           19  HOMBRE
# 347  SANTA ELENA  -2,22054988  -80,86332819           19   MUJER
# 348  SANTA ELENA  -2,24111132  -80,93387604            9   MUJER
# 382  SANTA ELENA  -2,22500738  -80,93727975           87  HOMBRE
# 399  SANTA ELENA  -2,24111132  -80,93387604           14   MUJER
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 65               SIN_DATO                 SIN_DATO          29/1/2023
# 103              SIN_DATO                 SIN_DATO          23/4/2023
# 124  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          28/2/2023
# 131              SIN_DATO                 SIN_DATO          21/4/2023
# 185             FALLECIDO                ASESINATO          13/2/2023
# 282  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           6/2/2023
# 347  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           6/2/2023
# 348  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           9/3/2023
# 382              SIN_DATO                 SIN_DATO          20/3/2023
# 399  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL           9/3/2023
#
#     Situación Actual Fecha Localización
# 65      DESAPARECIDO           SIN_DATO
# 103     DESAPARECIDO           SIN_DATO
# 124       ENCONTRADO          11/4/2023
# 131     DESAPARECIDO           SIN_DATO
# 185        FALLECIDO          16/2/2023
# 282       ENCONTRADO          22/2/2023
# 347       ENCONTRADO          22/2/2023
# 348       ENCONTRADO          22/3/2023
# 382     DESAPARECIDO           SIN_DATO
# 399       ENCONTRADO          22/3/2023
# ----------------------------------------------------------------------------------------------
# Provincia:SANTO DOMINGO DE LOS TSACHILAS
#                           Provincia      Latitud      Longitud  Edad Aprox.  \
# 2    SANTO DOMINGO DE LOS TSACHILAS    0,0091672    -79,391605           39
# 6    SANTO DOMINGO DE LOS TSACHILAS   -0,2683217   -79,1978398           42
# 51   SANTO DOMINGO DE LOS TSACHILAS   -0,2127289   -79,1369546           23
# 62   SANTO DOMINGO DE LOS TSACHILAS  -0,23876086  -79,17232865            8
# 115  SANTO DOMINGO DE LOS TSACHILAS   -0,2127289   -79,1369546           21
# 122  SANTO DOMINGO DE LOS TSACHILAS    0,0068737  -79,38423143           14
# 123  SANTO DOMINGO DE LOS TSACHILAS  -0,25895888  -79,18070545           40
# 126  SANTO DOMINGO DE LOS TSACHILAS  -0,25919634  -79,19594385           24
# 132  SANTO DOMINGO DE LOS TSACHILAS   -0,2601233   -79,1748467           32
# 137  SANTO DOMINGO DE LOS TSACHILAS   -0,2313345   -79,1730018           23
#
#        Sexo    Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 2    HOMBRE              SIN_DATO                 SIN_DATO           1/2/2023
# 6    HOMBRE              SIN_DATO                 SIN_DATO          13/3/2023
# 51    MUJER    PROBLEMAS SOCIALES              ALCOHOLISMO          29/1/2023
# 62    MUJER    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           8/2/2023
# 115  HOMBRE              SIN_DATO                 SIN_DATO          29/4/2023
# 122  HOMBRE    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           6/4/2023
# 123  HOMBRE  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          30/3/2023
# 126  HOMBRE              SIN_DATO                 SIN_DATO          30/4/2023
# 132   MUJER  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          14/1/2023
# 137   MUJER              SIN_DATO                 SIN_DATO          26/3/2023
#
#     Situación Actual Fecha Localización
# 2       DESAPARECIDO           SIN_DATO
# 6       DESAPARECIDO           SIN_DATO
# 51        ENCONTRADO           1/2/2023
# 62        ENCONTRADO           8/2/2023
# 115     DESAPARECIDO           SIN_DATO
# 122       ENCONTRADO           6/4/2023
# 123       ENCONTRADO          11/4/2023
# 126     DESAPARECIDO           SIN_DATO
# 132       ENCONTRADO           7/4/2023
# 137     DESAPARECIDO           SIN_DATO
# ----------------------------------------------------------------------------------------------
# Provincia:SUCUMBIOS
#      Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 23   SUCUMBIOS   0,08180581  -76,87016405           14   MUJER
# 31   SUCUMBIOS   0,25123144  -76,87599213            2   MUJER
# 42   SUCUMBIOS  -0,18829138  -76,64215118           13   MUJER
# 128  SUCUMBIOS   0,09918804  -76,88309669           13  HOMBRE
# 368  SUCUMBIOS   0,07561682  -76,89185932           15   MUJER
# 394  SUCUMBIOS    -0,038573     -76,59132           17   MUJER
# 435  SUCUMBIOS   0,07785044  -76,89436168           32   MUJER
# 484  SUCUMBIOS   -0,1845142  -76,63985252           15   MUJER
# 561  SUCUMBIOS     0,112781    -76,872708           11   MUJER
# 563  SUCUMBIOS  -0,19784689  -76,54499091           46   MUJER
#
#        Motivo Desaparción      Motivo Desaparción Obs. Fecha Desaparición  \
# 23   PROBLEMAS FAMILIARES              MALTRATO FISICO          27/2/2023
# 31               SIN_DATO                     SIN_DATO          27/2/2023
# 42   PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES          24/1/2023
# 128              SIN_DATO                     SIN_DATO          27/4/2023
# 368  PROBLEMAS FAMILIARES      PROBLEMAS SENTIMENTALES           3/2/2023
# 394  PROBLEMAS FAMILIARES         FAMILIA DISFUNSIONAL          28/2/2023
# 435  PROBLEMAS FAMILIARES         FAMILIA DISFUNSIONAL          18/3/2023
# 484  PROBLEMAS ACADÉMICOS  BULLYING (MALTRATO ESCOLAR)          17/4/2023
# 561  PROBLEMAS FAMILIARES         FAMILIA DISFUNSIONAL           2/1/2023
# 563   PROBLEMA ECÓNOMICOS                       DEUDAS           3/1/2023
#
#     Situación Actual Fecha Localización
# 23        ENCONTRADO           1/3/2023
# 31      DESAPARECIDO           SIN_DATO
# 42        ENCONTRADO          25/1/2023
# 128     DESAPARECIDO           SIN_DATO
# 368       ENCONTRADO          21/3/2023
# 394       ENCONTRADO           3/3/2023
# 435       ENCONTRADO           4/4/2023
# 484       ENCONTRADO          19/4/2023
# 561       ENCONTRADO           4/1/2023
# 563       ENCONTRADO           4/1/2023
# ----------------------------------------------------------------------------------------------
# Provincia:TUNGURAHUA
#       Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 21   TUNGURAHUA  -1,30969307  -78,51090218           15   MUJER
# 41   TUNGURAHUA    -1,271952   -78,6207711           12   MUJER
# 88   TUNGURAHUA   -1,3128375   -78,5064473           15   MUJER
# 199  TUNGURAHUA   -1,2704173   -78,6264312           28  HOMBRE
# 346  TUNGURAHUA   -1,2760056    -78,585247           14   MUJER
# 395  TUNGURAHUA   -1,1032401   -78,5320107           16  HOMBRE
# 407  TUNGURAHUA   -1,2080043   -78,6030584           57   MUJER
# 408  TUNGURAHUA  -1,27176774  -78,73576654           17   MUJER
# 438  TUNGURAHUA   -1,2466443   -78,6164659           15   MUJER
# 447  TUNGURAHUA  -1,34865844  -78,66970237           34   MUJER
#
#        Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 21     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          22/2/2023
# 41             EXTRAVIADA       PERSONA EXTRAVIADA          16/1/2023
# 88     PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           6/3/2023
# 199    PROBLEMAS SOCIALES              ALCOHOLISMO          15/3/2023
# 346    PROBLEMAS SOCIALES              ALCOHOLISMO           4/3/2023
# 395    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES           2/2/2023
# 407  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          19/3/2023
# 408    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          12/3/2023
# 438  PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL          21/3/2023
# 447  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          17/2/2023
#
#     Situación Actual Fecha Localización
# 21        ENCONTRADO           2/3/2023
# 41        ENCONTRADO          19/1/2023
# 88        ENCONTRADO          13/3/2023
# 199       ENCONTRADO          17/3/2023
# 346       ENCONTRADO          20/3/2023
# 395       ENCONTRADO           6/3/2023
# 407       ENCONTRADO          21/3/2023
# 408       ENCONTRADO          22/3/2023
# 438       ENCONTRADO          25/3/2023
# 447       ENCONTRADO          25/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:ZAMORA CHINCHIPE
#              Provincia      Latitud      Longitud  Edad Aprox.    Sexo  \
# 334   ZAMORA CHINCHIPE  -3,82529668   -78,7593655           28   MUJER
# 335   ZAMORA CHINCHIPE  -3,82529668   -78,7593655            2  HOMBRE
# 440   ZAMORA CHINCHIPE  -3,59246606  -78,56978338           15   MUJER
# 602   ZAMORA CHINCHIPE  -3,89101654  -78,78571593           13   MUJER
# 615   ZAMORA CHINCHIPE   -3,6201077  -78,58502062           16   MUJER
# 1246  ZAMORA CHINCHIPE  -3,89117737  -78,78449651           13   MUJER
# 1302  ZAMORA CHINCHIPE  -4,00129496   -78,6403992           15   MUJER
# 2221  ZAMORA CHINCHIPE  -4,86353692  -79,13011976           45   MUJER
# 2390  ZAMORA CHINCHIPE  -4,31764146  -78,66601657           13   MUJER
# 2539  ZAMORA CHINCHIPE   -3,8364565  -78,76201812           13   MUJER
#
#         Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 334   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          13/3/2023
# 335   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          13/3/2023
# 440   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          20/3/2023
# 602   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          15/4/2023
# 615   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          25/2/2023
# 1246  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          10/2/2023
# 1302  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES           3/1/2023
# 2221              SIN_DATO                 SIN_DATO           2/4/2023
# 2390    PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES          12/4/2023
# 2539  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          20/2/2023
#
#      Situación Actual Fecha Localización
# 334        ENCONTRADO          14/4/2023
# 335        ENCONTRADO          14/4/2023
# 440        ENCONTRADO          23/3/2023
# 602        ENCONTRADO          20/4/2023
# 615        ENCONTRADO           3/3/2023
# 1246       ENCONTRADO          14/2/2023
# 1302       ENCONTRADO          17/2/2023
# 2221     DESAPARECIDO           SIN_DATO
# 2390       ENCONTRADO          17/4/2023
# 2539       ENCONTRADO          23/2/2023
# ----------------------------------------------------------------------------------------------
# Provincia:ZONA NO DELIMITADA
#                Provincia      Latitud      Longitud  Edad Aprox.   Sexo  \
# 998   ZONA NO DELIMITADA  -0,60305737  -79,60357419           23  MUJER
# 1020  ZONA NO DELIMITADA  -0,60305737  -79,60357419            1  MUJER
# 1185  ZONA NO DELIMITADA  -2,34097341  -79,24397279           13  MUJER
#
#         Motivo Desaparción  Motivo Desaparción Obs. Fecha Desaparición  \
# 998   PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          31/1/2023
# 1020  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          31/1/2023
# 1185  PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES          28/1/2023
#
#      Situación Actual Fecha Localización
# 998        ENCONTRADO           2/2/2023
# 1020       ENCONTRADO           2/2/2023
# 1185       ENCONTRADO          11/2/2023
# ----------------------------------------------------------------------------------------------
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001B8D631DE10>

# %% [markdown]
# ### Crear un nuevo dataset de perfiles
# #### un perfil es 1 registro en el cual se encuentra relacionado los valores de la columna Provincia, Edad Aprox., Sexo, Motivo Desaparicion
# #### La columna cantidad representa las veces que se repite cada perfil de persona propensa a desaparecer

# %%
# Group the records by age and sex, and count the number of occurrences
grouped_counts = df.groupby(['Provincia','Edad Aprox.', 'Sexo','Motivo Desaparción']).size().reset_index(name='Cantidad').sort_values('Cantidad', ascending=False)

# Print the grouped counts
print(grouped_counts)
# Out:
#                Provincia  Edad Aprox.    Sexo    Motivo Desaparción  Cantidad
# 463               GUAYAS           14   MUJER  PROBLEMAS FAMILIARES        35
# 1082           PICHINCHA           15   MUJER    PROBLEMAS SOCIALES        33
# 454               GUAYAS           13   MUJER  PROBLEMAS FAMILIARES        29
# 1081           PICHINCHA           15   MUJER  PROBLEMAS FAMILIARES        28
# 1088           PICHINCHA           16   MUJER  PROBLEMAS FAMILIARES        25
# ...                  ...          ...     ...                   ...       ...
# 576               GUAYAS           34  HOMBRE   PROBLEMA ECÓNOMICOS         1
# 575               GUAYAS           34  HOMBRE             FALLECIDO         1
# 574               GUAYAS           33  HOMBRE              SIN_DATO         1
# 573               GUAYAS           33  HOMBRE  PROBLEMAS FAMILIARES         1
# 1488  ZONA NO DELIMITADA           23   MUJER  PROBLEMAS FAMILIARES         1
#
# [1489 rows x 5 columns]

# %% [markdown]
# #### Se imprime las columnas que tiene el nuevo dataset

# %%
columnas = grouped_counts.columns
print(columnas)
# Out:
# Index(['Provincia', 'Edad Aprox.', 'Sexo', 'Motivo Desaparción', 'Cantidad'], dtype='object')

# %% [markdown]
# ### Se normaliza la columna Cantidad, por cada 100000 habitantes
# #### para normalizar se divide el registro de cantidad perteneciente a cada perfil por la poblacion de la provincia a la que pertenece ese perfil
# #### A la cantidad normalizada se la multiplica por 100000
#
# #### Los registros de la columna Cantidad_Normalizada permiten ajustar los valores de cantidad en relacion a la poblacion de cada provincia y se calcula la tasa poblacional por cada 100000 habitantes
#
# #### Si tomamos en cuenta el registro 1488 perteneciente a ZONA NO DELIMITADA, la cantidad es 1 pero comparado con el registro 573  perteneciente a GUAYAS, la cantidad tambien es 1. Al normalizar el valor de ZONA NO DELIMITADA es mayor que el valor de GUAYAS.
# #### Porque una persona desapareciada en  ZONA NO DELIMITADA, estadisticamente representa mas que 1 persona desaparecidad en GUAYAS

# %%
poblacion_provincias = {
    'AZUAY': 881394,
    'BOLIVAR': 209933,
    'CAÑAR': 281396,
    'CARCHI': 186869,
    'COTOPAXI': 488716,
    'CHIMBORAZO': 524004,
    'EL ORO': 715751,
    'ESMERALDAS': 643654,
    'GUAYAS': 4387434,
    'IMBABURA': 476257,
    'LOJA': 521154,
    'LOS RIOS': 921763,
    'MANABI': 1562079,
    'MORONA SANTIAGO': 196535,
    'NAPO': 133705,
    'PASTAZA': 114202,
    'PICHINCHA': 3228233,
    'TUNGURAHUA': 590600,
    'ZAMORA CHINCHIPE': 120416,
    'GALAPAGOS': 33042,
    'SUCUMBIOS': 230503,
    'ORELLANA': 161338,
    'SANTO DOMINGO DE LOS TSACHILAS': 458580,
    'SANTA ELENA': 401178,
    'ZONA NO DELIMITADA': 41907
}

#print("\nPoblación total en millones de habitantes")
poblacion_total = sum(poblacion_provincias.values())
#print(poblacion_total)
#print('----------------------------------------------------------------------------------------------')

#print("\nCalcula la proporción de población para cada provincia")
grouped_counts['Proporcion_Poblacion'] = grouped_counts['Provincia'].map(poblacion_provincias)
#print(grouped_counts)

#print(grouped_counts['Proporcion_Poblacion'])
#print('----------------------------------------------------------------------------------------------')

#print("\nCalcula la cantidad normalizada por cada 100,000 habitantes")
grouped_counts['Cantidad_Normalizada'] = grouped_counts['Cantidad'] / grouped_counts['Proporcion_Poblacion'] * 100000
#print(grouped_counts['Cantidad_Normalizada'])
#print('----------------------------------------------------------------------------------------------')

#print("\nElimina la columna de proporción de población")
grouped_counts = grouped_counts.drop('Proporcion_Poblacion', axis=1)
#print('----------------------------------------------------------------------------------------------')

print("\nMuestra el DataFrame resultante")
print(grouped_counts)
print('----------------------------------------------------------------------------------------------')
# Out:
# Muestra el DataFrame resultante
#                Provincia  Edad Aprox.    Sexo    Motivo Desaparción  Cantidad  \
# 463               GUAYAS           14   MUJER  PROBLEMAS FAMILIARES        35
# 1082           PICHINCHA           15   MUJER    PROBLEMAS SOCIALES        33
# 454               GUAYAS           13   MUJER  PROBLEMAS FAMILIARES        29
# 1081           PICHINCHA           15   MUJER  PROBLEMAS FAMILIARES        28
# 1088           PICHINCHA           16   MUJER  PROBLEMAS FAMILIARES        25
# ...                  ...          ...     ...                   ...       ...
# 576               GUAYAS           34  HOMBRE   PROBLEMA ECÓNOMICOS         1
# 575               GUAYAS           34  HOMBRE             FALLECIDO         1
# 574               GUAYAS           33  HOMBRE              SIN_DATO         1
# 573               GUAYAS           33  HOMBRE  PROBLEMAS FAMILIARES         1
# 1488  ZONA NO DELIMITADA           23   MUJER  PROBLEMAS FAMILIARES         1
#
#       Cantidad_Normalizada
# 463               0.797733
# 1082              1.022231
# 454               0.660979
# 1081              0.867348
# 1088              0.774417
# ...                    ...
# 576               0.022792
# 575               0.022792
# 574               0.022792
# 573               0.022792
# 1488              2.386236
#
# [1489 rows x 6 columns]
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# ### Se obtiene la moda de cada provincia
# #### Representa el perfil que mas se repite en cada provincia

# %%
columnas = grouped_counts.columns
#print(columnas)

# Agrupar por provincia
grupo_provincia = grouped_counts.groupby('Provincia')
#print(grupo_provincia)
#print('----------------------------------------------------------------------------------------------')

# Crear una lista para almacenar los resultados
resultados = []

# Iterar sobre cada grupo
for provincia, grupo in grupo_provincia:
    # Obtener el registro más repetido por provincia
    registro_mas_repetido = grupo.loc[grupo['Cantidad_Normalizada'].idxmax()]

    # Agregar el registro al resultado final
    resultados.append(registro_mas_repetido)

# Crear un DataFrame con los resultados
resultados_df = pd.DataFrame(resultados)

# Mostrar el DataFrame resultante
print(resultados_df)
# Out:
#                            Provincia  Edad Aprox.    Sexo  \
# 21                             AZUAY           15   MUJER
# 100                          BOLIVAR           17   MUJER
# 115                           CARCHI           16   MUJER
# 132                            CAÑAR           14   MUJER
# 172                       CHIMBORAZO           15   MUJER
# 256                         COTOPAXI           15   MUJER
# 317                           EL ORO           16   MUJER
# 391                       ESMERALDAS           17   MUJER
# 425                        GALAPAGOS           49  HOMBRE
# 463                           GUAYAS           14   MUJER
# 690                         IMBABURA           13   MUJER
# 763                             LOJA           16   MUJER
# 801                         LOS RIOS           14   MUJER
# 865                           MANABI           13   MUJER
# 931                  MORONA SANTIAGO           14   MUJER
# 967                             NAPO           14   MUJER
# 992                         ORELLANA           14   MUJER
# 1013                         PASTAZA           17   MUJER
# 1082                       PICHINCHA           15   MUJER
# 1300                     SANTA ELENA           16   MUJER
# 1337  SANTO DOMINGO DE LOS TSACHILAS           15   MUJER
# 1412                       SUCUMBIOS           13   MUJER
# 1442                      TUNGURAHUA           15   MUJER
# 1479                ZAMORA CHINCHIPE           13   MUJER
# 1487              ZONA NO DELIMITADA           13   MUJER
#
#         Motivo Desaparción  Cantidad  Cantidad_Normalizada
# 21    PROBLEMAS FAMILIARES         7              0.794196
# 100     PROBLEMAS SOCIALES         2              0.952685
# 115   PROBLEMAS FAMILIARES         1              0.535134
# 132   PROBLEMAS FAMILIARES         8              2.842969
# 172     PROBLEMAS SOCIALES         8              1.526706
# 256   PROBLEMAS FAMILIARES         5              1.023089
# 317   PROBLEMAS FAMILIARES        13              1.816274
# 391   PROBLEMAS FAMILIARES         6              0.932178
# 425             EXTRAVIADA         1              3.026451
# 463   PROBLEMAS FAMILIARES        35              0.797733
# 690     PROBLEMAS SOCIALES         4              0.839883
# 763   PROBLEMAS FAMILIARES         6              1.151291
# 801   PROBLEMAS FAMILIARES        14              1.518829
# 865   PROBLEMAS FAMILIARES        11              0.704190
# 931   PROBLEMAS FAMILIARES         7              3.561707
# 967     PROBLEMAS SOCIALES         3              2.243746
# 992   PROBLEMAS FAMILIARES         2              1.239634
# 1013  PROBLEMAS FAMILIARES         3              2.626924
# 1082    PROBLEMAS SOCIALES        33              1.022231
# 1300  PROBLEMAS FAMILIARES         5              1.246330
# 1337  PROBLEMAS FAMILIARES        12              2.616774
# 1412  PROBLEMAS FAMILIARES         7              3.036837
# 1442    PROBLEMAS SOCIALES         9              1.523874
# 1479  PROBLEMAS FAMILIARES         3              2.491363
# 1487  PROBLEMAS FAMILIARES         1              2.386236

# %% [markdown]
# ### Como resultado se obtiene que en la provincia de Pichincha el perfil de persona mas suceptible a desaparecer es:
# #### Tener 15 años, ser mujer y tener problemas familiares
#
# ### Los resultado por provincia se listan en el dataframe superior

# %%
import matplotlib.pyplot as plt

# Ordenar el DataFrame por cantidad normalizada
resultados_df = resultados_df.sort_values(by='Cantidad_Normalizada', ascending=True)

# Obtener los valores necesarios para el gráfico
provincias = resultados_df['Provincia']
cantidades_normalizadas = resultados_df['Cantidad_Normalizada']

# Configurar el gráfico de barras horizontales
plt.figure(figsize=(10, 8))
plt.barh(provincias, cantidades_normalizadas)
plt.xlabel('Cantidad Normalizada')
plt.ylabel('Provincia')
plt.title('Registro con mayor Cantidad Normalizada por provincia')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Ordenar el DataFrame por cantidad normalizada
resultados_df = resultados_df.sort_values(by='Cantidad_Normalizada', ascending=True)

# Obtener los valores necesarios para el gráfico
provincias = resultados_df['Provincia']
cantidades_normalizadas = resultados_df['Cantidad_Normalizada']

# Configurar el gráfico de barras horizontales
plt.figure(figsize=(10, 8))
plt.barh(provincias, cantidades_normalizadas)
plt.xlabel('Cantidad Normalizada')
plt.ylabel('Provincia')
plt.title('Registro con mayor Cantidad Normalizada por provincia')

# Mostrar el gráfico
plt.show()

# %%
# Contar cuantos registros de la columna edad hay por provincia
conteo = datos['Provincia'].value_counts()
print(conteo)
# Out:
# PICHINCHA                         642
# GUAYAS                            533
# CHIMBORAZO                        147
# SANTO DOMINGO DE LOS TSACHILAS    136
# AZUAY                             116
# MANABI                            113
# EL ORO                            113
# LOS RIOS                          109
# ESMERALDAS                         83
# TUNGURAHUA                         74
# MORONA SANTIAGO                    74
# LOJA                               72
# IMBABURA                           67
# COTOPAXI                           66
# SUCUMBIOS                          37
# SANTA ELENA                        33
# NAPO                               32
# CAÑAR                              29
# BOLIVAR                            25
# CARCHI                             21
# PASTAZA                            21
# ORELLANA                           20
# ZAMORA CHINCHIPE                   11
# GALAPAGOS                           4
# ZONA NO DELIMITADA                  3
# Name: Provincia, dtype: int64

# %%
# Normalizar el conteo
poblacion_total = 17800000
factor_ajuste = 100000/poblacion_total
#factor_ajuste = 100000

min_valor = conteo.min()
max_valor = conteo.max()

normalizado = (conteo / len(datos)) * (factor_ajuste)
print(normalizado)
# Out:
# PICHINCHA                         0.001397
# GUAYAS                            0.001160
# CHIMBORAZO                        0.000320
# SANTO DOMINGO DE LOS TSACHILAS    0.000296
# AZUAY                             0.000252
# MANABI                            0.000246
# EL ORO                            0.000246
# LOS RIOS                          0.000237
# ESMERALDAS                        0.000181
# TUNGURAHUA                        0.000161
# MORONA SANTIAGO                   0.000161
# LOJA                              0.000157
# IMBABURA                          0.000146
# COTOPAXI                          0.000144
# SUCUMBIOS                         0.000081
# SANTA ELENA                       0.000072
# NAPO                              0.000070
# CAÑAR                             0.000063
# BOLIVAR                           0.000054
# CARCHI                            0.000046
# PASTAZA                           0.000046
# ORELLANA                          0.000044
# ZAMORA CHINCHIPE                  0.000024
# GALAPAGOS                         0.000009
# ZONA NO DELIMITADA                0.000007
# Name: Provincia, dtype: float64

# %% [markdown]
# ## Proporción de registros por provincia
# ### los datos fueron normalizados y su rango es registros encontrados por cada 100000 habitantes

# %%
#plt.figure(figsize=(8, 6))

# Crear el gráfico de barras
plt.barh(normalizado.index, normalizado)

# Configurar etiquetas y título
plt.ylabel('Provincia')
plt.xlabel('Proporción')
plt.title('Proporción de registros por provincia')

# Agregar los valores normalizados al extremo derecho de cada fila
for i, value in enumerate(normalizado):
    plt.annotate(f'{value:.6f}', xy=(value, i), xytext=(5, 0), textcoords='offset points', ha='left', va='center')

# Mostrar el gráfico
plt.show()

# %%
# Verificar columnas con valores nulos
columnas_nulos = datos.columns[datos.isnull().any()]
print("Columnas con valores nulos:")
print(columnas_nulos)

# Verificar columnas con valores vacíos
columnas_vacios = datos.columns[datos.eq('').any()]
print("Columnas con valores vacíos:")
print(columnas_vacios)

# Verificar columnas con valor "SIN_DATO"
columnas_sin_dato = datos.columns[datos.eq('SIN_DATO').any()]
print("Columnas con valor 'SIN_DATO':")
print(columnas_sin_dato)
# Out:
# Columnas con valores nulos:
# Index([], dtype='object')
# Columnas con valores vacíos:
# Index([], dtype='object')
# Columnas con valor 'SIN_DATO':
# Index(['Motivo Desaparción', 'Motivo Desaparción Obs.', 'Fecha Localización'], dtype='object')

# %%
# Agrupar y contar cada columna
columnas_contadas = {}
for columna in datos.columns:
    columna_contada = datos[columna].value_counts()
    columnas_contadas[columna] = columna_contada

# Imprimir los resultados
for columna, conteo in columnas_contadas.items():
    print(f"Columna: {columna}")
    print(conteo)
    print()
# Out:
# Columna: Provincia
# PICHINCHA                         642
# GUAYAS                            533
# CHIMBORAZO                        147
# SANTO DOMINGO DE LOS TSACHILAS    136
# AZUAY                             116
# MANABI                            113
# EL ORO                            113
# LOS RIOS                          109
# ESMERALDAS                         83
# TUNGURAHUA                         74
# MORONA SANTIAGO                    74
# LOJA                               72
# IMBABURA                           67
# COTOPAXI                           66
# SUCUMBIOS                          37
# SANTA ELENA                        33
# NAPO                               32
# CAÑAR                              29
# BOLIVAR                            25
# CARCHI                             21
# PASTAZA                            21
# ORELLANA                           20
# ZAMORA CHINCHIPE                   11
# GALAPAGOS                           4
# ZONA NO DELIMITADA                  3
# Name: Provincia, dtype: int64
#
# Columna: Latitud
# -0,327644      11
# -0,7140022     11
# -0,4616728      9
# -2,168974       9
# -2,3074378      9
#                ..
# -0,9085624      1
# -3,24934223     1
# -3,25967496     1
# -0,2342572      1
# -0,30864288     1
# Name: Latitud, Length: 2076, dtype: int64
#
# Columna: Longitud
# -80,109357      11
# -78,5673547     11
# -79,8397207      9
# -78,1202307      9
# -76,9931074      9
#                 ..
# -78,63765332     1
# -80,83480597     1
# -79,2035207      1
# -77,8081363      1
# -78,54081268     1
# Name: Longitud, Length: 2054, dtype: int64
#
# Columna: Edad Aprox.
# 15    290
# 16    267
# 14    254
# 13    178
# 17    175
#      ...
# 95      1
# 82      1
# 84      1
# 70      1
# 91      1
# Name: Edad Aprox., Length: 91, dtype: int64
#
# Columna: Sexo
# MUJER     1527
# HOMBRE    1054
# Name: Sexo, dtype: int64
#
# Columna: Motivo Desaparción
# PROBLEMAS FAMILIARES             1092
# PROBLEMAS SOCIALES                728
# SIN_DATO                          381
# FALLECIDO                         133
# DISCAPACIDADES Y ENFERMEDADES      93
# PROBLEMAS PSICOLÓGICOS             51
# EXTRAVIADA                         49
# PROBLEMA ECÓNOMICOS                20
# PROBLEMAS ACADÉMICOS               17
# FISCALÍA                           10
# PERDIDO                             7
# Name: Motivo Desaparción, dtype: int64
#
# Columna: Motivo Desaparción Obs.
# FAMILIA DISFUNSIONAL           629
# INFLUENCIA DE AMISTADES        514
# PROBLEMAS SENTIMENTALES        392
# SIN_DATO                       381
# DELINCUENCIA                    97
# NO DETERMINADA                  72
# OTRAS ENFERMEDADES MENTALES     54
# DROGADICCION                    54
# ALCOHOLISMO                     39
# MALTRATO FISICO                 38
# ACCIDENTAL                      32
# PROBLEMAS DE CONDUCTA           30
# PERSONA EXTRAVIADA              29
# ALZHEIMER                       24
# MALTRATO PSICOLOGICO            24
# MIGRACION                       21
# DEUDAS                          20
# ASESINATO                       18
# DEPRESION                       17
# RETARDOS MENTALES               14
# BAJO RENDIMIENTO                14
# HOSPITALIZADO                   13
# FISCALÍA                        10
# NINOS NINAS PERDIDOS             7
# MALTRATO SEXUAL                  7
# ACCIDENTADO                      4
# PANDILLAS                        3
# HOMICIDIO ASESINATO              3
# BULLYING (MALTRATO ESCOLAR)      3
# DETENIDO                         3
# SUICIDIO                         3
# AUTISMO                          2
# MUERTE NATURAL                   2
# MALTRATO PATRIMONIAL             2
# HOMICIDIO                        2
# BIPOLARIDAD                      2
# FEMICIDIO                        1
# SINDROME DE DOWN                 1
# Name: Motivo Desaparción Obs., dtype: int64
#
# Columna: Fecha Desaparición
# 26/3/2023    40
# 17/2/2023    34
# 14/2/2023    33
# 26/2/2023    32
# 13/4/2023    32
#              ..
# 26/1/2023    13
# 1/1/2023     13
# 22/1/2023    13
# 16/4/2023    13
# 27/2/2023    12
# Name: Fecha Desaparición, Length: 120, dtype: int64
#
# Columna: Situación Actual
# ENCONTRADO      2067
# DESAPARECIDO     381
# FALLECIDO        133
# Name: Situación Actual, dtype: int64
#
# Columna: Fecha Localización
# SIN_DATO     381
# 5/2/2023      41
# 28/3/2023     39
# 28/2/2023     37
# 26/4/2023     36
#             ...
# 6/5/2023       2
# 14/5/2023      2
# 1/1/2023       1
# 16/5/2023      1
# 13/5/2023      1
# Name: Fecha Localización, Length: 137, dtype: int64

# %%
# Agrupar por "Motivo Desaparción" y "Motivo Desaparción Obs.", contar y ordenar
grupo_motivo = datos.groupby(["Motivo Desaparción", "Motivo Desaparción Obs."]).size().reset_index(name='conteo')
grupo_motivo = grupo_motivo.sort_values(by='conteo', ascending=False)

# Imprimir los resultados
for index, row in grupo_motivo.iterrows():
    motivo_desaparicion = row["Motivo Desaparción"]
    motivo_desaparicion_obs = row["Motivo Desaparción Obs."]
    conteo = row["conteo"]
    print(f"Motivo Desaparción: {motivo_desaparicion} - Motivo Desaparción Obs.: {motivo_desaparicion_obs} - Conte: {conteo}")
# Out:
# Motivo Desaparción: PROBLEMAS FAMILIARES - Motivo Desaparción Obs.: FAMILIA DISFUNSIONAL - Conte: 629
# Motivo Desaparción: PROBLEMAS SOCIALES - Motivo Desaparción Obs.: INFLUENCIA DE AMISTADES - Conte: 514
# Motivo Desaparción: PROBLEMAS FAMILIARES - Motivo Desaparción Obs.: PROBLEMAS SENTIMENTALES - Conte: 392
# Motivo Desaparción: SIN_DATO - Motivo Desaparción Obs.: SIN_DATO - Conte: 381
# Motivo Desaparción: PROBLEMAS SOCIALES - Motivo Desaparción Obs.: DELINCUENCIA - Conte: 97
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: NO DETERMINADA - Conte: 72
# Motivo Desaparción: PROBLEMAS SOCIALES - Motivo Desaparción Obs.: DROGADICCION - Conte: 54
# Motivo Desaparción: DISCAPACIDADES Y ENFERMEDADES - Motivo Desaparción Obs.: OTRAS ENFERMEDADES MENTALES - Conte: 54
# Motivo Desaparción: PROBLEMAS SOCIALES - Motivo Desaparción Obs.: ALCOHOLISMO - Conte: 39
# Motivo Desaparción: PROBLEMAS FAMILIARES - Motivo Desaparción Obs.: MALTRATO FISICO - Conte: 38
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: ACCIDENTAL - Conte: 32
# Motivo Desaparción: PROBLEMAS PSICOLÓGICOS - Motivo Desaparción Obs.: PROBLEMAS DE CONDUCTA - Conte: 30
# Motivo Desaparción: EXTRAVIADA - Motivo Desaparción Obs.: PERSONA EXTRAVIADA - Conte: 29
# Motivo Desaparción: PROBLEMAS FAMILIARES - Motivo Desaparción Obs.: MALTRATO PSICOLOGICO - Conte: 24
# Motivo Desaparción: DISCAPACIDADES Y ENFERMEDADES - Motivo Desaparción Obs.: ALZHEIMER - Conte: 24
# Motivo Desaparción: PROBLEMAS SOCIALES - Motivo Desaparción Obs.: MIGRACION - Conte: 21
# Motivo Desaparción: PROBLEMA ECÓNOMICOS - Motivo Desaparción Obs.: DEUDAS - Conte: 20
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: ASESINATO - Conte: 18
# Motivo Desaparción: PROBLEMAS PSICOLÓGICOS - Motivo Desaparción Obs.: DEPRESION - Conte: 17
# Motivo Desaparción: DISCAPACIDADES Y ENFERMEDADES - Motivo Desaparción Obs.: RETARDOS MENTALES - Conte: 14
# Motivo Desaparción: PROBLEMAS ACADÉMICOS - Motivo Desaparción Obs.: BAJO RENDIMIENTO - Conte: 14
# Motivo Desaparción: EXTRAVIADA - Motivo Desaparción Obs.: HOSPITALIZADO - Conte: 13
# Motivo Desaparción: FISCALÍA - Motivo Desaparción Obs.: FISCALÍA - Conte: 10
# Motivo Desaparción: PERDIDO - Motivo Desaparción Obs.: NINOS NINAS PERDIDOS - Conte: 7
# Motivo Desaparción: PROBLEMAS FAMILIARES - Motivo Desaparción Obs.: MALTRATO SEXUAL - Conte: 7
# Motivo Desaparción: EXTRAVIADA - Motivo Desaparción Obs.: ACCIDENTADO - Conte: 4
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: HOMICIDIO ASESINATO - Conte: 3
# Motivo Desaparción: PROBLEMAS SOCIALES - Motivo Desaparción Obs.: PANDILLAS - Conte: 3
# Motivo Desaparción: EXTRAVIADA - Motivo Desaparción Obs.: DETENIDO - Conte: 3
# Motivo Desaparción: PROBLEMAS ACADÉMICOS - Motivo Desaparción Obs.: BULLYING (MALTRATO ESCOLAR) - Conte: 3
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: SUICIDIO - Conte: 3
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: HOMICIDIO - Conte: 2
# Motivo Desaparción: PROBLEMAS PSICOLÓGICOS - Motivo Desaparción Obs.: BIPOLARIDAD - Conte: 2
# Motivo Desaparción: PROBLEMAS PSICOLÓGICOS - Motivo Desaparción Obs.: AUTISMO - Conte: 2
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: MUERTE NATURAL - Conte: 2
# Motivo Desaparción: PROBLEMAS FAMILIARES - Motivo Desaparción Obs.: MALTRATO PATRIMONIAL - Conte: 2
# Motivo Desaparción: DISCAPACIDADES Y ENFERMEDADES - Motivo Desaparción Obs.: SINDROME DE DOWN  - Conte: 1
# Motivo Desaparción: FALLECIDO - Motivo Desaparción Obs.: FEMICIDIO - Conte: 1

# %%
# Obtener el valor más repetido en cada columna
columnas_repeticiones = {}
for columna in datos.columns:
    valor_mas_repetido = datos[columna].mode()
    columnas_repeticiones[columna] = valor_mas_repetido

# Imprimir los resultados
for columna, valor_repetido in columnas_repeticiones.items():
    print(f"Columna: {columna}")
    for valor in valor_repetido:
        conteo = datos[columna].value_counts()[valor]
        print(f"Dato: {valor} - Conte: {conteo}")
    print()
# Out:
# Columna: Provincia
# Dato: PICHINCHA - Conte: 642
#
# Columna: Latitud
# Dato: -0,327644 - Conte: 11
# Dato: -0,7140022 - Conte: 11
#
# Columna: Longitud
# Dato: -78,5673547 - Conte: 11
# Dato: -80,109357 - Conte: 11
#
# Columna: Edad Aprox.
# Dato: 15 - Conte: 290
#
# Columna: Sexo
# Dato: MUJER - Conte: 1527
#
# Columna: Motivo Desaparción
# Dato: PROBLEMAS FAMILIARES - Conte: 1092
#
# Columna: Motivo Desaparción Obs.
# Dato: FAMILIA DISFUNSIONAL - Conte: 629
#
# Columna: Fecha Desaparición
# Dato: 26/3/2023 - Conte: 40
#
# Columna: Situación Actual
# Dato: ENCONTRADO - Conte: 2067
#
# Columna: Fecha Localización
# Dato: SIN_DATO - Conte: 381

# %% [markdown]
# ## El perfil de la persona mas suceptible a desaparecer es:
#
# ### Provincia: Pichincha
# ### Edad: 15
# ### Sexo: MUJER
# ### Motivo Desaparción: PROBLEMAS FAMILIARES
# ### Motivo Desaparción Obs.: FAMILIA DISFUNSIONAL
# ### Fecha Desaparición: 26/3/2023
# ### Mes: Marzo

# %% [markdown]
# ## El perfil de la persona mas suceptible a desaparecer por cada provincia es:

# %%
# Agrupar por provincia
grupo_provincia = datos.groupby('Provincia')

# Iterar sobre cada grupo
for provincia, grupo in grupo_provincia:
    print(f"Provincia: {provincia}")
    print("-------------------------------")

    # Iterar sobre cada columna
    for columna in grupo.columns:
        if columna != 'Provincia':
            conteo = grupo[columna].value_counts()
            max_repetidos = conteo[conteo == conteo.max()]

            print(f"Columna: {columna}")
            print(f"Dato(s) más repetido(s):")
            for dato, count in max_repetidos.items():
                print(f"Dato: {dato} - Conteo: {count}")
            
            print("-------------------------------")
    
    print("\n")
# Out:
# Provincia: AZUAY
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -2,863187 - Conteo: 3
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,964005 - Conteo: 3
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 17
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 62
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 45
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 28
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 18/3/2023 - Conteo: 5
# Dato: 6/2/2023 - Conteo: 5
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 91
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 20
# -------------------------------
#
#
# Provincia: BOLIVAR
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -1,5585611 - Conteo: 2
# Dato: -1,70880111 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,0093181 - Conteo: 2
# Dato: -79,06013337 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 16 - Conteo: 4
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 18
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 8
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 6
# Dato: FAMILIA DISFUNSIONAL - Conteo: 6
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 3/1/2023 - Conteo: 2
# Dato: 17/1/2023 - Conteo: 2
# Dato: 5/2/2023 - Conteo: 2
# Dato: 25/2/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 20
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 5
# -------------------------------
#
#
# Provincia: CARCHI
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: 0,8150687 - Conteo: 5
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -77,7165925 - Conteo: 5
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 17 - Conteo: 3
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: HOMBRE - Conteo: 12
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 8
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 6
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 28/1/2023 - Conteo: 2
# Dato: 25/4/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 14
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 6
# -------------------------------
#
#
# Provincia: CAÑAR
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -2,74420725 - Conteo: 1
# Dato: -2,74052076 - Conteo: 1
# Dato: -2,58240517 - Conteo: 1
# Dato: -2,75958984 - Conteo: 1
# Dato: -2,35771587 - Conteo: 1
# Dato: -2,71080908 - Conteo: 1
# Dato: -2,4298261 - Conteo: 1
# Dato: -2,5548842 - Conteo: 1
# Dato: -2,72406863 - Conteo: 1
# Dato: -2,75073402 - Conteo: 1
# Dato: -2,40576704 - Conteo: 1
# Dato: -2,54524522 - Conteo: 1
# Dato: -2,71926851 - Conteo: 1
# Dato: -2,74097888 - Conteo: 1
# Dato: -2,50501168 - Conteo: 1
# Dato: -2,41859254 - Conteo: 1
# Dato: -2,42748586 - Conteo: 1
# Dato: -2,70274361 - Conteo: 1
# Dato: -2,73624995 - Conteo: 1
# Dato: -2,73703459 - Conteo: 1
# Dato: -2,51183374 - Conteo: 1
# Dato: -2,42751698 - Conteo: 1
# Dato: -2,44971945 - Conteo: 1
# Dato: -2,52724371 - Conteo: 1
# Dato: -2,73786305 - Conteo: 1
# Dato: -2,4967536 - Conteo: 1
# Dato: -2,55980032 - Conteo: 1
# Dato: -2,43107356 - Conteo: 1
# Dato: -2,73292233 - Conteo: 1
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,8606357 - Conteo: 1
# Dato: -78,83325571 - Conteo: 1
# Dato: -78,94870461 - Conteo: 1
# Dato: -78,88694113 - Conteo: 1
# Dato: -79,39788832 - Conteo: 1
# Dato: -78,88273737 - Conteo: 1
# Dato: -79,33107737 - Conteo: 1
# Dato: -78,93657397 - Conteo: 1
# Dato: -78,82717864 - Conteo: 1
# Dato: -78,84819369 - Conteo: 1
# Dato: -79,02279347 - Conteo: 1
# Dato: -78,92688311 - Conteo: 1
# Dato: -78,8886835 - Conteo: 1
# Dato: -78,84136465 - Conteo: 1
# Dato: -78,94309644 - Conteo: 1
# Dato: -79,34606481 - Conteo: 1
# Dato: -79,34154929 - Conteo: 1
# Dato: -78,91191218 - Conteo: 1
# Dato: -78,81497607 - Conteo: 1
# Dato: -78,81363278 - Conteo: 1
# Dato: -78,92759869 - Conteo: 1
# Dato: -79,34290006 - Conteo: 1
# Dato: -79,3188858 - Conteo: 1
# Dato: -78,91291016 - Conteo: 1
# Dato: -78,84501452 - Conteo: 1
# Dato: -79,47998164 - Conteo: 1
# Dato: -78,93751322 - Conteo: 1
# Dato: -79,3379348 - Conteo: 1
# Dato: -78,86408039 - Conteo: 1
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 14 - Conteo: 9
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 22
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 20
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SENTIMENTALES - Conteo: 10
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 3/1/2023 - Conteo: 2
# Dato: 5/3/2023 - Conteo: 2
# Dato: 13/4/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 25
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 4
# -------------------------------
#
#
# Provincia: CHIMBORAZO
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -1,6650227 - Conteo: 7
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,6588786 - Conteo: 7
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 16 - Conteo: 19
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 89
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 56
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 46
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 26/3/2023 - Conteo: 22
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 111
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 24
# -------------------------------
#
#
# Provincia: COTOPAXI
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,9411949 - Conteo: 5
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,2316042 - Conteo: 5
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 9
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 35
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 26
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: FAMILIA DISFUNSIONAL - Conteo: 19
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 17/4/2023 - Conteo: 3
# Dato: 15/4/2023 - Conteo: 3
# Dato: 14/2/2023 - Conteo: 3
# Dato: 16/1/2023 - Conteo: 3
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 57
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 6
# -------------------------------
#
#
# Provincia: EL ORO
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -3,2581112 - Conteo: 3
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,9553924 - Conteo: 3
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 16 - Conteo: 17
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 65
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 56
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: FAMILIA DISFUNSIONAL - Conteo: 37
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 21/4/2023 - Conteo: 5
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 100
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 9
# -------------------------------
#
#
# Provincia: ESMERALDAS
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: 0,804828 - Conteo: 2
# Dato: 0,533362 - Conteo: 2
# Dato: 0,8680071 - Conteo: 2
# Dato: 0,96655255 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,940308 - Conteo: 2
# Dato: -79,5227688 - Conteo: 2
# Dato: -79,8464804 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 17 - Conteo: 12
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 50
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 28
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 28
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 28/3/2023 - Conteo: 3
# Dato: 3/3/2023 - Conteo: 3
# Dato: 21/1/2023 - Conteo: 3
# Dato: 20/2/2023 - Conteo: 3
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 49
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 28
# -------------------------------
#
#
# Provincia: GALAPAGOS
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,7386498 - Conteo: 1
# Dato: 0,13864128 - Conteo: 1
# Dato: -0,7432918 - Conteo: 1
# Dato: -0,8674715 - Conteo: 1
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -90,3126872 - Conteo: 1
# Dato: -91,3480686 - Conteo: 1
# Dato: -90,3156893 - Conteo: 1
# Dato: -89,436391 - Conteo: 1
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 41 - Conteo: 1
# Dato: 49 - Conteo: 1
# Dato: 15 - Conteo: 1
# Dato: 26 - Conteo: 1
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: HOMBRE - Conteo: 3
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 2
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 2
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 12/4/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 4
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 13/4/2023 - Conteo: 2
# -------------------------------
#
#
# Provincia: GUAYAS
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -2,168974 - Conteo: 9
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,8397207 - Conteo: 9
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 14 - Conteo: 50
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 277
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 254
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: FAMILIA DISFUNSIONAL - Conteo: 177
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 3/3/2023 - Conteo: 11
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 385
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 98
# -------------------------------
#
#
# Provincia: IMBABURA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: 0,3552973 - Conteo: 6
# Dato: 0,2343005 - Conteo: 6
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,1250848 - Conteo: 6
# Dato: -78,2610672 - Conteo: 6
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 16 - Conteo: 7
# Dato: 13 - Conteo: 7
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 38
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 26
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 20
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 19/2/2023 - Conteo: 4
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 57
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 8
# -------------------------------
#
#
# Provincia: LOJA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -3,9952065 - Conteo: 4
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,2022123 - Conteo: 4
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 8
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 43
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 40
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: FAMILIA DISFUNSIONAL - Conteo: 29
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 26/2/2023 - Conteo: 5
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 60
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 7
# -------------------------------
#
#
# Provincia: LOS RIOS
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -1,0336635 - Conteo: 4
# Dato: -0,8857721 - Conteo: 4
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,4506989 - Conteo: 4
# Dato: -79,4872619 - Conteo: 4
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 22
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 77
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 60
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: FAMILIA DISFUNSIONAL - Conteo: 36
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 12/3/2023 - Conteo: 4
# Dato: 1/2/2023 - Conteo: 4
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 88
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 18
# -------------------------------
#
#
# Provincia: MANABI
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,7140022 - Conteo: 11
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -80,109357 - Conteo: 11
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 13 - Conteo: 13
# Dato: 15 - Conteo: 13
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 73
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 73
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: FAMILIA DISFUNSIONAL - Conteo: 36
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 13/2/2023 - Conteo: 7
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 95
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 16
# -------------------------------
#
#
# Provincia: MORONA SANTIAGO
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -2,3074378 - Conteo: 9
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,1202307 - Conteo: 9
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 14 - Conteo: 14
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 57
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 28
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 19
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 13/4/2023 - Conteo: 4
# Dato: 3/4/2023 - Conteo: 4
# Dato: 23/1/2023 - Conteo: 4
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 59
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 14
# -------------------------------
#
#
# Provincia: NAPO
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -1,03133483 - Conteo: 2
# Dato: -0,9962972 - Conteo: 2
# Dato: -0,978408 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -77,73698759 - Conteo: 2
# Dato: -77,8136035 - Conteo: 2
# Dato: -77,852852 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 14 - Conteo: 4
# Dato: 16 - Conteo: 4
# Dato: 15 - Conteo: 4
# Dato: 13 - Conteo: 4
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 21
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 12
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 11
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 27/4/2023 - Conteo: 2
# Dato: 8/3/2023 - Conteo: 2
# Dato: 24/2/2023 - Conteo: 2
# Dato: 1/4/2023 - Conteo: 2
# Dato: 10/3/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 27
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 22/2/2023 - Conteo: 3
# Dato: SIN_DATO - Conteo: 3
# -------------------------------
#
#
# Provincia: ORELLANA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,4616728 - Conteo: 9
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -76,9931074 - Conteo: 9
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 4
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 13
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 11
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 4
# Dato: PROBLEMAS SENTIMENTALES - Conteo: 4
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 26/1/2023 - Conteo: 1
# Dato: 3/4/2023 - Conteo: 1
# Dato: 16/4/2023 - Conteo: 1
# Dato: 25/3/2023 - Conteo: 1
# Dato: 20/4/2023 - Conteo: 1
# Dato: 26/4/2023 - Conteo: 1
# Dato: 22/4/2023 - Conteo: 1
# Dato: 9/4/2023 - Conteo: 1
# Dato: 14/2/2023 - Conteo: 1
# Dato: 2/2/2023 - Conteo: 1
# Dato: 29/1/2023 - Conteo: 1
# Dato: 2/1/2023 - Conteo: 1
# Dato: 5/3/2023 - Conteo: 1
# Dato: 8/1/2023 - Conteo: 1
# Dato: 1/1/2023 - Conteo: 1
# Dato: 10/2/2023 - Conteo: 1
# Dato: 21/2/2023 - Conteo: 1
# Dato: 5/1/2023 - Conteo: 1
# Dato: 30/4/2023 - Conteo: 1
# Dato: 20/2/2023 - Conteo: 1
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 19
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 15/2/2023 - Conteo: 2
# Dato: 1/3/2023 - Conteo: 2
# -------------------------------
#
#
# Provincia: PASTAZA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -1,47947312 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,01176509 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 17 - Conteo: 4
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 15
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 9
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 7
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 20/3/2023 - Conteo: 2
# Dato: 5/3/2023 - Conteo: 2
# Dato: 28/1/2023 - Conteo: 2
# Dato: 13/2/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 19
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 5/4/2023 - Conteo: 2
# Dato: 6/3/2023 - Conteo: 2
# Dato: 31/1/2023 - Conteo: 2
# Dato: 14/3/2023 - Conteo: 2
# -------------------------------
#
#
# Provincia: PICHINCHA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,327644 - Conteo: 11
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,5673547 - Conteo: 11
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 78
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 367
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 278
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 216
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 11/3/2023 - Conteo: 11
# Dato: 17/4/2023 - Conteo: 11
# Dato: 15/4/2023 - Conteo: 11
# Dato: 15/3/2023 - Conteo: 11
# Dato: 8/2/2023 - Conteo: 11
# Dato: 4/3/2023 - Conteo: 11
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 559
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 59
# -------------------------------
#
#
# Provincia: SANTA ELENA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -2,24111132 - Conteo: 3
# Dato: -2,242607 - Conteo: 3
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -80,93387604 - Conteo: 3
# Dato: -80,887785 - Conteo: 3
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 16 - Conteo: 6
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 22
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 19
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SENTIMENTALES - Conteo: 11
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 21/4/2023 - Conteo: 3
# Dato: 9/3/2023 - Conteo: 3
# Dato: 24/4/2023 - Conteo: 3
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 23
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 8
# -------------------------------
#
#
# Provincia: SANTO DOMINGO DE LOS TSACHILAS
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,2521882 - Conteo: 8
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,1879383 - Conteo: 8
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 17
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 80
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 59
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 33
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 26/3/2023 - Conteo: 7
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 97
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 33
# -------------------------------
#
#
# Provincia: SUCUMBIOS
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,2971506 - Conteo: 2
# Dato: -0,18829138 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -76,65877151 - Conteo: 2
# Dato: -76,64215118 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 13 - Conteo: 8
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 30
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 21
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SENTIMENTALES - Conteo: 12
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 3/1/2023 - Conteo: 3
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 25
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: SIN_DATO - Conteo: 10
# -------------------------------
#
#
# Provincia: TUNGURAHUA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -1,3128375 - Conteo: 4
# Dato: -1,2760056 - Conteo: 4
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,5064473 - Conteo: 4
# Dato: -78,585247 - Conteo: 4
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 15 - Conteo: 12
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 51
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SOCIALES - Conteo: 34
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: INFLUENCIA DE AMISTADES - Conteo: 25
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 6/3/2023 - Conteo: 4
# Dato: 14/2/2023 - Conteo: 4
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 70
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 3/4/2023 - Conteo: 4
# -------------------------------
#
#
# Provincia: ZAMORA CHINCHIPE
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -3,82529668 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -78,7593655 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 13 - Conteo: 4
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 9
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 8
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SENTIMENTALES - Conteo: 8
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 13/3/2023 - Conteo: 2
# Dato: 20/2/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 10
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 14/4/2023 - Conteo: 2
# -------------------------------
#
#
# Provincia: ZONA NO DELIMITADA
# -------------------------------
# Columna: Latitud
# Dato(s) más repetido(s):
# Dato: -0,60305737 - Conteo: 2
# -------------------------------
# Columna: Longitud
# Dato(s) más repetido(s):
# Dato: -79,60357419 - Conteo: 2
# -------------------------------
# Columna: Edad Aprox.
# Dato(s) más repetido(s):
# Dato: 23 - Conteo: 1
# Dato: 1 - Conteo: 1
# Dato: 13 - Conteo: 1
# -------------------------------
# Columna: Sexo
# Dato(s) más repetido(s):
# Dato: MUJER - Conteo: 3
# -------------------------------
# Columna: Motivo Desaparción
# Dato(s) más repetido(s):
# Dato: PROBLEMAS FAMILIARES - Conteo: 3
# -------------------------------
# Columna: Motivo Desaparción Obs.
# Dato(s) más repetido(s):
# Dato: PROBLEMAS SENTIMENTALES - Conteo: 3
# -------------------------------
# Columna: Fecha Desaparición
# Dato(s) más repetido(s):
# Dato: 31/1/2023 - Conteo: 2
# -------------------------------
# Columna: Situación Actual
# Dato(s) más repetido(s):
# Dato: ENCONTRADO - Conteo: 3
# -------------------------------
# Columna: Fecha Localización
# Dato(s) más repetido(s):
# Dato: 2/2/2023 - Conteo: 2
# -------------------------------

# %%
# Función para categorizar las edades
def categorizar_edad(edad):
    if edad < 12:
        return 'Niños'
    elif 12 <= edad <= 17:
        return 'Jóvenes'
    else:
        rango_superior = (edad // 5) * 5
        rango_inferior = rango_superior - 4
        return f'{rango_inferior} a {rango_superior}'

# Aplicar la función a la columna 'Edad Aprox.' y crear una nueva columna 'Categoría Edad'
datos['Categoría Edad'] = datos['Edad Aprox.'].apply(categorizar_edad)

# Imprimir el dataframe resultante
print(datos.head(15))
# Out:
#                          Provincia      Latitud      Longitud  Edad Aprox.  \
# 0                        PICHINCHA   -0,2188216   -78,5135489           17
# 1                        PICHINCHA  -0,26909023  -78,54001523           17
# 2   SANTO DOMINGO DE LOS TSACHILAS    0,0091672    -79,391605           39
# 3                        PICHINCHA  -0,17504166  -78,47478184           14
# 4                       ESMERALDAS    0,9873857  -79,65649069           28
# 5                           GUAYAS   -2,1225293    -80,000135           28
# 6   SANTO DOMINGO DE LOS TSACHILAS   -0,2683217   -79,1978398           42
# 7                           GUAYAS   -2,1258684   -79,9227452           16
# 8                       CHIMBORAZO   -1,6604411   -78,6563855           12
# 9                        PICHINCHA  -0,21867203  -78,50517916           16
# 10                        IMBABURA    0,3475869   -78,1160486           23
# 11                          GUAYAS  -2,11391357  -79,98889708           21
# 12                          MANABI  -0,95853387  -80,74264526           17
# 13                          MANABI  -0,95853387  -80,74264526            2
# 14                           AZUAY  -2,89018174  -79,02961728            1
#
#       Sexo      Motivo Desaparción  Motivo Desaparción Obs.  \
# 0   HOMBRE                SIN_DATO                 SIN_DATO
# 1    MUJER    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES
# 2   HOMBRE                SIN_DATO                 SIN_DATO
# 3    MUJER      PROBLEMAS SOCIALES  INFLUENCIA DE AMISTADES
# 4   HOMBRE                SIN_DATO                 SIN_DATO
# 5   HOMBRE               FALLECIDO           NO DETERMINADA
# 6   HOMBRE                SIN_DATO                 SIN_DATO
# 7    MUJER    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES
# 8   HOMBRE    PROBLEMAS FAMILIARES          MALTRATO FISICO
# 9    MUJER                SIN_DATO                 SIN_DATO
# 10  HOMBRE      PROBLEMAS SOCIALES             DELINCUENCIA
# 11   MUJER  PROBLEMAS PSICOLÓGICOS                DEPRESION
# 12   MUJER    PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL
# 13  HOMBRE    PROBLEMAS FAMILIARES     FAMILIA DISFUNSIONAL
# 14   MUJER    PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES
#
#    Fecha Desaparición Situación Actual Fecha Localización Categoría Edad
# 0           24/1/2023     DESAPARECIDO           SIN_DATO        Jóvenes
# 1            2/2/2023       ENCONTRADO           7/2/2023        Jóvenes
# 2            1/2/2023     DESAPARECIDO           SIN_DATO        31 a 35
# 3           16/3/2023       ENCONTRADO          17/3/2023        Jóvenes
# 4            7/2/2023     DESAPARECIDO           SIN_DATO        21 a 25
# 5           15/3/2023        FALLECIDO          24/3/2023        21 a 25
# 6           13/3/2023     DESAPARECIDO           SIN_DATO        36 a 40
# 7            2/3/2023       ENCONTRADO          20/3/2023        Jóvenes
# 8            9/2/2023       ENCONTRADO           9/2/2023        Jóvenes
# 9           17/3/2023     DESAPARECIDO           SIN_DATO        Jóvenes
# 10          10/3/2023       ENCONTRADO          16/3/2023        16 a 20
# 11          18/3/2023       ENCONTRADO          28/3/2023        16 a 20
# 12          26/2/2023       ENCONTRADO          22/3/2023        Jóvenes
# 13          26/2/2023       ENCONTRADO          22/3/2023          Niños
# 14          18/3/2023       ENCONTRADO           6/4/2023          Niños

# %%
# Imprimir las columnas "Edad" y "Categoría Edad"
# print(datos[['Provincia','Edad Aprox.', 'Categoría Edad']].head(30))

# %% [markdown]
# ## Categorizar los datos por rangos de edad.

# %%
# Categorizar la columna de Edad Aproximada
def categorizar_edad(edad):
    if edad <= 12:
        return 'Niños'
    elif 13 <= edad <= 18:
        return 'Jóvenes'
    else:
        rango_superior = (edad // 5) * 5
        r+ango_inferior = rango_superior - 4
        return f'{rango_inferior} a {rango_superior}'

datos['Categoría Edad'] = datos['Edad Aprox.'].apply(categorizar_edad)

# Agrupar por provincia y categoría de edad, y contar el número de ocurrencias
agrupado = datos.groupby(['Provincia', 'Categoría Edad']).size().unstack()

# Crear el histograma
agrupado.plot(kind='bar', stacked=True, figsize=(12, 8))

# Configurar el título y etiquetas de los ejes
plt.title('Distribución de Edades por Provincia')
plt.xlabel('Provincia')
plt.ylabel('Cantidad')

# Mostrar el histograma
plt.show()
# Out:
#   Cell In[157], line 9
#     r+ango_inferior = rango_superior - 4
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# Categorizar la columna de Edad Aproximada
def categorizar_edad(edad):
    if edad <= 12:
        return 'Niños'
    elif 13 <= edad <= 18:
        return 'Jóvenes'
    else:
        rango_superior = (edad // 5) * 5
        rango_inferior = rango_superior - 4
        return f'{rango_inferior} a {rango_superior}'

datos['Categoría Edad'] = datos['Edad Aprox.'].apply(categorizar_edad)

# Obtener las provincias únicas
provincias = datos['Provincia'].unique()

# Imprimir el conteo de registros por categoría de edad para cada provincia
for provincia in provincias:
    print(f'Provincia: {provincia}')
    filtro = datos['Provincia'] == provincia
    conteo = datos[filtro]['Categoría Edad'].value_counts()
    print(conteo)
    print()

# %%
# Categorizar la columna de Edad Aproximada
def categorizar_edad(edad):
    if edad <= 12:
        return 'Niños'
    elif 13 <= edad <= 18:
        return 'Jóvenes'
    else:
        rango_superior = (edad // 5) * 5
        rango_inferior = rango_superior - 4
        return f'{rango_inferior} a {rango_superior}'

datos['Categoría Edad'] = datos['Edad Aprox.'].apply(categorizar_edad)

# Agrupar por provincia y categoría de edad, contar los registros y resetear el índice
conteo = datos.groupby(['Provincia', 'Categoría Edad'])['Categoría Edad'].count().reset_index(name='edad')

# Imprimir la tabla resultante
# print(conteo.head(45))

# %%
# Categorizar la columna de Edad Aproximada
def categorizar_edad(edad):
    if edad <= 12:
        return 'niños'
    elif 13 <= edad <= 18:
        return 'jovenes'
    else:
        rango_superior = (edad // 5) * 5
        rango_inferior = rango_superior - 4
        return f'{rango_inferior} a {rango_superior}'

datos['Categoría Edad'] = datos['Edad Aprox.'].apply(categorizar_edad)

# Agrupar por provincia, categoría de edad y contar
conteo_edad = datos.groupby(['Provincia', 'Categoría Edad']).size().reset_index(name='edad')

# Ordenar descendente por categoría de edad y alfabéticamente por provincia
conteo_edad = conteo_edad.sort_values(['Categoría Edad', 'Provincia'], ascending=[False, True])

# Imprimir los resultados
# print(conteo_edad.to_string(index=True))

# %%
# Leer el archivo CSV
df = pd.read_csv('data/mdg_personasdesaparecidas_pm_2023_enero_abril.csv', encoding='latin1', sep=';')

# Convertir la columna 'Fecha Desaparición' al formato de fecha
df['Fecha Desaparición'] = pd.to_datetime(df['Fecha Desaparición'], dayfirst=True)
# Crear una nueva columna 'Mes' que contenga el mes de la fecha de desaparición
df['Mes'] = df['Fecha Desaparición'].dt.month
# Contar el número de desapariciones por mes
meses_desapariciones = df['Mes'].value_counts()
print(meses_desapariciones)
# Obtener el mes con mayor cantidad de desapariciones
mes_max_desapariciones = meses_desapariciones.idxmax()

# Imprimir el resultado
print("El mes con mayor cantidad de desapariciones fue:", mes_max_desapariciones)

# %%
# Leer el archivo CSV
data = pd.read_csv('data/mdg_personasdesaparecidas_pm_2023_enero_abril.csv', encoding='latin1', sep=';')

# Convertir la columna 'Fecha Desaparición' al formato de fecha
data['Fecha Desaparición'] = pd.to_datetime(data['Fecha Desaparición'], dayfirst=True)

# Crear una nueva columna 'Mes' que contenga el mes de la fecha de desaparición
data['Mes'] = data['Fecha Desaparición'].dt.month

# Filtrar los datos solo para los meses de enero, febrero, marzo y abril
meses_seleccionados = [1, 2, 3, 4]
data_seleccionada = data[data['Mes'].isin(meses_seleccionados)]

# Contar el número de desapariciones por mes
meses_desapariciones = data_seleccionada['Mes'].value_counts()

# Ordenar los meses en orden ascendente
meses_desapariciones = meses_desapariciones.sort_index()

# Obtener los nombres de los meses
nombres_meses = [calendar.month_name[mes] for mes in meses_desapariciones.index]

# Graficar los meses y el número de desaparecidos
plt.bar(nombres_meses, meses_desapariciones.values)
plt.xlabel('Mes')
plt.ylabel('Número de desaparecidos')
plt.title('Número de desaparecidos por mes (Enero - Abril) del 2023')

# Mostrar el número de desaparecidos encima de cada barra
for i, v in enumerate(meses_desapariciones.values):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()
